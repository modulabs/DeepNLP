# %% [markdown]
# # Bag of words meets bag of popcorn
# ## Part 2 / Word Vector
#
#
# **word2vec 모델 **
#
# **논문**
# *  Efficient Estimation of Word Representations in Vector Space (2013, Mikolov)
#     * 초기버전
#     * CBOW ,Skip-gram
# *  Distributed Representations of Words and Phrases and their Compositionality (2013,Mikolov)
#     * 튜닝기법이 추가
#
# **word2vec 관련 참고 자료**
#
# * [Efficient Estimation of Word Representations in Vector Space](https://arxiv.org/pdf/1301.3781v3.pdf)
# * [Distributed Representations of Words and Phrases and their Compositionality](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf)
# * [Word2Vec tensorflow 한글 번역본](https://tensorflowkorea.gitbooks.io/tensorflow-kr/g3doc/tutorials/word2vec/)
# * [Word2Vec 블로그 정리글 - Word2Vec으로 문장 정리하기](https://ratsgo.github.io/natural%20language%20processing/2017/03/08/word2vec/)
# * [Word2Vec 블로그 정리글 - Word embedding관련 정리](http://nohhj.blogspot.kr/2015/08/word-embedding.html)
#
#
# 1. 각 단어들을 원 핫인코딩 방식 혹은 Bag of words 방식으로 나타낼 경우 size가 매우 크고 벡터가 너무 sparse해서 neural net 성능이 잘 나오지 않는다.
# 2. 단어 주변이 비슷하면 그 단어들은 의미가 유사하다는 아이디어
# 3. 단어를 벡터로 바꿔주는 엠베딩(Embedding)과정
# 4. Word2Vec은 분산 된 텍스트 표현을 사용하여 개념 간 유사성을 본다. 예를 들어, 파리와 프랑스가 베를린과 독일이 (수도와 나라) 같은 방식으로 관련되어 있음을 이해한다.
#
# ![image.png](https://camo.githubusercontent.com/97ec511f00892d0560dab2419288e434ded52255/68747470733a2f2f312e62702e626c6f6773706f742e636f6d2f2d51374638756c44366643302f5567766e564353476d58492f41414141414141414162672f4d43574c545942756668732f73313630302f696d61676530302e676966)
# ![image.png](http://i.imgur.com/agTBWiT.png)
#
# 5 CBOW와 Skip-gram 기법 사용
#
# * CBOW
#     * CBOW(continuous bag-of-words)
#     * 전체 텍스트로 하나의 단어를 예측한다.
#     * 작은 데이터셋일수록 유리
# * Skip-Gram
#     * 타겟 단어들로 부터 원본 단어들을 역으로 유추하는 과정
#     * 큰 규모의 데이터셋일수록 유리
# ![image.png](https://camo.githubusercontent.com/1a8235d525ad46485e764e5008cbc29c8c17a5be/68747470733a2f2f692e696d6775722e636f6d2f795859314c78562e706e67)

# %%
# 참고 : https://gist.github.com/yong27/7869662
# http://www.racketracer.com/2016/07/06/pandas-in-parallel/
from multiprocessing import Pool
import numpy as np

def _apply_df(args):
    df, func, kwargs = args
    return df.apply(func, **kwargs)

def apply_by_multiprocessing(df, func, **kwargs):
    # 키워드 항목 중 workers 파라메터를 꺼냄
    workers = kwargs.pop('workers')
    # 위에서 가져온 workers 수로 프로세스 풀을 정의
    pool = Pool(processes=workers)
    # 실행할 함수와 데이터프레임을 워커의 수 만큼 나눠 작업
    result = pool.map(_apply_df, [(d, func, kwargs)
            for d in np.array_split(df, workers)])
    pool.close()
    # 작업 결과를 합쳐서 반환
    return pd.concat(list(result))

# %%
from kaggleBagofWord import kaggleBagofWord
##전처리과정에 사용하는 것들을 class화

# %%
import pandas as pd

train = pd.read_csv('data/labeledTrainData.tsv', 
                    header=0, delimiter='\t', quoting=3)
test = pd.read_csv('data/testData.tsv', 
                   header=0, delimiter='\t', quoting=3)
unlabeled_train = pd.read_csv('data/unlabeledTrainData.tsv', 
                              header=0, delimiter='\t', quoting=3)

print(train.shape)
print(test.shape)
print(unlabeled_train.shape)

print(train['review'].size)
print(test['review'].size)
print(unlabeled_train['review'].size)
# Out:
# (25000, 3)
# (25000, 2)
# (50000, 2)
# 25000
# 25000
# 50000

# %%
kaggleBagofWord.review_to_wordlist(train['review'][0])[:10]
# Out:
# ['with', 'all', 'this', 'stuff', 'go', 'down', 'at', 'the', 'moment', 'with']

# %%
sentences = []
for review in train["review"]:
    sentences += kaggleBagofWord.review_to_sentences(
        review, remove_stopwords=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.happierabroad.com"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'12.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'music.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)

# %%
sentences
# Out:
# [['with',
#   'all',
#   'this',
#   'stuff',
#   'go',
#   'down',
#   'at',
#   'the',
#   'moment',
#   'with',
#   'mj',
#   'i',
#   've',
#   'start',
#   'listen',
#   'to',
#   'his',
#   'music',
#   'watch',
#   'the',
#   'odd',
#   'documentari',
#   'here',
#   'and',
#   'there',
#   'watch',
#   'the',
#   'wiz',
#   'and',
#   'watch',
#   'moonwalk',
#   'again'],
#  ['mayb',
#   'i',
#   'just',
#   'want',
#   'to',
#   'get',
#   'a',
#   'certain',
#   'insight',
#   'into',
#   'this',
#   'guy',
#   'who',
#   'i',
#   'thought',
#   'was',
#   'realli',
#   'cool',
#   'in',
#   'the',
#   'eighti',
#   'just',
#   'to',
#   'mayb',
#   'make',
#   'up',
#   'my',
#   'mind',
#   'whether',
#   'he',
#   'is',
#   'guilti',
#   'or',
#   'innoc'],
#  ['moonwalk',
#   'is',
#   'part',
#   'biographi',
#   'part',
#   'featur',
#   'film',
#   'which',
#   'i',
#   'rememb',
#   'go',
#   'to',
#   'see',
#   'at',
#   'the',
#   'cinema',
#   'when',
#   'it',
#   'was',
#   'origin',
#   'releas'],
#  ['some',
#   'of',
#   'it',
#   'has',
#   'subtl',
#   'messag',
#   'about',
#   'mj',
#   's',
#   'feel',
#   'toward',
#   'the',
#   'press',
#   'and',
#   'also',
#   'the',
#   'obvious',
#   'messag',
#   'of',
#   'drug',
#   'are',
#   'bad',
#   'm',
#   'kay',
#   'visual',
#   'impress',
#   'but',
#   'of',
#   'cours',
#   'this',
#   'is',
#   'all',
#   'about',
#   'michael',
#   'jackson',
#   'so',
#   'unless',
#   'you',
#   'remot',
#   'like',
#   'mj',
#   'in',
#   'anyway',
#   'then',
#   'you',
#   'are',
#   'go',
#   'to',
#   'hate',
#   'this',
#   'and',
#   'find',
#   'it',
#   'bore'],
#  ['some',
#   'may',
#   'call',
#   'mj',
#   'an',
#   'egotist',
#   'for',
#   'consent',
#   'to',
#   'the',
#   'make',
#   'of',
#   'this',
#   'movi',
#   'but',
#   'mj',
#   'and',
#   'most',
#   'of',
#   'his',
#   'fan',
#   'would',
#   'say',
#   'that',
#   'he',
#   'made',
#   'it',
#   'for',
#   'the',
#   'fan',
#   'which',
#   'if',
#   'true',
#   'is',
#   'realli',
#   'nice',
#   'of',
#   'him',
#   'the',
#   'actual',
#   'featur',
#   'film',
#   'bit',
#   'when',
#   'it',
#   'final',
#   'start',
#   'is',
#   'onli',
#   'on',
#   'for',
#   'minut',
#   'or',
#   'so',
#   'exclud',
#   'the',
#   'smooth',
#   'crimin',
#   'sequenc',
#   'and',
#   'joe',
#   'pesci',
#   'is',
#   'convinc',
#   'as',
#   'a',
#   'psychopath',
#   'all',
#   'power',
#   'drug',
#   'lord'],
#  ['whi', 'he', 'want', 'mj', 'dead', 'so', 'bad', 'is', 'beyond', 'me'],
#  ['becaus', 'mj', 'overheard', 'his', 'plan'],
#  ['nah',
#   'joe',
#   'pesci',
#   's',
#   'charact',
#   'rant',
#   'that',
#   'he',
#   'want',
#   'peopl',
#   'to',
#   'know',
#   'it',
#   'is',
#   'he',
#   'who',
#   'is',
#   'suppli',
#   'drug',
#   'etc',
#   'so',
#   'i',
#   'dunno',
#   'mayb',
#   'he',
#   'just',
#   'hate',
#   'mj',
#   's',
#   'music',
#   'lot',
#   'of',
#   'cool',
#   'thing',
#   'in',
#   'this',
#   'like',
#   'mj',
#   'turn',
#   'into',
#   'a',
#   'car',
#   'and',
#   'a',
#   'robot',
#   'and',
#   'the',
#   'whole',
#   'speed',
#   'demon',
#   'sequenc'],
#  ['also',
#   'the',
#   'director',
#   'must',
#   'have',
#   'had',
#   'the',
#   'patienc',
#   'of',
#   'a',
#   'saint',
#   'when',
#   'it',
#   'came',
#   'to',
#   'film',
#   'the',
#   'kiddi',
#   'bad',
#   'sequenc',
#   'as',
#   'usual',
#   'director',
#   'hate',
#   'work',
#   'with',
#   'one',
#   'kid',
#   'let',
#   'alon',
#   'a',
#   'whole',
#   'bunch',
#   'of',
#   'them',
#   'perform',
#   'a',
#   'complex',
#   'danc',
#   'scene',
#   'bottom',
#   'line',
#   'this',
#   'movi',
#   'is',
#   'for',
#   'peopl',
#   'who',
#   'like',
#   'mj',
#   'on',
#   'one',
#   'level',
#   'or',
#   'anoth',
#   'which',
#   'i',
#   'think',
#   'is',
#   'most',
#   'peopl'],
#  ['if', 'not', 'then', 'stay', 'away'],
#  ['it',
#   'doe',
#   'tri',
#   'and',
#   'give',
#   'off',
#   'a',
#   'wholesom',
#   'messag',
#   'and',
#   'iron',
#   'mj',
#   's',
#   'bestest',
#   'buddi',
#   'in',
#   'this',
#   'movi',
#   'is',
#   'a',
#   'girl'],
#  ['michael',
#   'jackson',
#   'is',
#   'truli',
#   'one',
#   'of',
#   'the',
#   'most',
#   'talent',
#   'peopl',
#   'ever',
#   'to',
#   'grace',
#   'this',
#   'planet',
#   'but',
#   'is',
#   'he',
#   'guilti'],
#  ['well',
#   'with',
#   'all',
#   'the',
#   'attent',
#   'i',
#   've',
#   'gave',
#   'this',
#   'subject',
#   'hmmm',
#   'well',
#   'i',
#   'don',
#   't',
#   'know',
#   'becaus',
#   'peopl',
#   'can',
#   'be',
#   'differ',
#   'behind',
#   'close',
#   'door',
#   'i',
#   'know',
#   'this',
#   'for',
#   'a',
#   'fact'],
#  ['he',
#   'is',
#   'either',
#   'an',
#   'extrem',
#   'nice',
#   'but',
#   'stupid',
#   'guy',
#   'or',
#   'one',
#   'of',
#   'the',
#   'most',
#   'sickest',
#   'liar'],
#  ['i', 'hope', 'he', 'is', 'not', 'the', 'latter'],
#  ['the',
#   'classic',
#   'war',
#   'of',
#   'the',
#   'world',
#   'by',
#   'timothi',
#   'hine',
#   'is',
#   'a',
#   'veri',
#   'entertain',
#   'film',
#   'that',
#   'obvious',
#   'goe',
#   'to',
#   'great',
#   'effort',
#   'and',
#   'length',
#   'to',
#   'faith',
#   'recreat',
#   'h',
#   'g',
#   'well',
#   'classic',
#   'book'],
#  ['mr', 'hine', 'succeed', 'in', 'do', 'so'],
#  ['i',
#   'and',
#   'those',
#   'who',
#   'watch',
#   'his',
#   'film',
#   'with',
#   'me',
#   'appreci',
#   'the',
#   'fact',
#   'that',
#   'it',
#   'was',
#   'not',
#   'the',
#   'standard',
#   'predict',
#   'hollywood',
#   'fare',
#   'that',
#   'come',
#   'out',
#   'everi',
#   'year',
#   'e',
#   'g'],
#  ['the',
#   'spielberg',
#   'version',
#   'with',
#   'tom',
#   'cruis',
#   'that',
#   'had',
#   'onli',
#   'the',
#   'slightest',
#   'resembl',
#   'to',
#   'the',
#   'book'],
#  ['obvious', 'everyon', 'look', 'for', 'differ', 'thing', 'in', 'a', 'movi'],
#  ['those',
#   'who',
#   'envis',
#   'themselv',
#   'as',
#   'amateur',
#   'critic',
#   'look',
#   'onli',
#   'to',
#   'critic',
#   'everyth',
#   'they',
#   'can'],
#  ['other',
#   'rate',
#   'a',
#   'movi',
#   'on',
#   'more',
#   'import',
#   'base',
#   'like',
#   'be',
#   'entertain',
#   'which',
#   'is',
#   'whi',
#   'most',
#   'peopl',
#   'never',
#   'agre',
#   'with',
#   'the',
#   'critic'],
#  ['we',
#   'enjoy',
#   'the',
#   'effort',
#   'mr',
#   'hine',
#   'put',
#   'into',
#   'be',
#   'faith',
#   'to',
#   'h',
#   'g'],
#  ['well',
#   'classic',
#   'novel',
#   'and',
#   'we',
#   'found',
#   'it',
#   'to',
#   'be',
#   'veri',
#   'entertain'],
#  ['this',
#   'made',
#   'it',
#   'easi',
#   'to',
#   'overlook',
#   'what',
#   'the',
#   'critic',
#   'perceiv',
#   'to',
#   'be',
#   'it',
#   'shortcom'],
#  ['the',
#   'film',
#   'start',
#   'with',
#   'a',
#   'manag',
#   'nichola',
#   'bell',
#   'give',
#   'welcom',
#   'investor',
#   'robert',
#   'carradin',
#   'to',
#   'primal',
#   'park'],
#  ['a',
#   'secret',
#   'project',
#   'mutat',
#   'a',
#   'primal',
#   'anim',
#   'use',
#   'fossil',
#   'dna',
#   'like',
#   'jurassik',
#   'park',
#   'and',
#   'some',
#   'scientist',
#   'resurrect',
#   'one',
#   'of',
#   'natur',
#   's',
#   'most',
#   'fearsom',
#   'predat',
#   'the',
#   'sabretooth',
#   'tiger',
#   'or',
#   'smilodon'],
#  ['scientif',
#   'ambit',
#   'turn',
#   'dead',
#   'howev',
#   'and',
#   'when',
#   'the',
#   'high',
#   'voltag',
#   'fenc',
#   'is',
#   'open',
#   'the',
#   'creatur',
#   'escap',
#   'and',
#   'begin',
#   'savag',
#   'stalk',
#   'it',
#   'prey',
#   'the',
#   'human',
#   'visitor',
#   'tourist',
#   'and',
#   'scientif',
#   'meanwhil',
#   'some',
#   'youngster',
#   'enter',
#   'in',
#   'the',
#   'restrict',
#   'area',
#   'of',
#   'the',
#   'secur',
#   'center',
#   'and',
#   'are',
#   'attack',
#   'by',
#   'a',
#   'pack',
#   'of',
#   'larg',
#   'pre',
#   'histor',
#   'anim',
#   'which',
#   'are',
#   'deadlier',
#   'and',
#   'bigger'],
#  ['in',
#   'addit',
#   'a',
#   'secur',
#   'agent',
#   'staci',
#   'haiduk',
#   'and',
#   'her',
#   'mate',
#   'brian',
#   'wimmer',
#   'fight',
#   'hard',
#   'against',
#   'the',
#   'carnivor',
#   'smilodon'],
#  ['the',
#   'sabretooth',
#   'themselv',
#   'of',
#   'cours',
#   'are',
#   'the',
#   'real',
#   'star',
#   'star',
#   'and',
#   'they',
#   'are',
#   'astound',
#   'terrifi',
#   'though',
#   'not',
#   'convinc'],
#  ['the',
#   'giant',
#   'anim',
#   'savag',
#   'are',
#   'stalk',
#   'it',
#   'prey',
#   'and',
#   'the',
#   'group',
#   'run',
#   'afoul',
#   'and',
#   'fight',
#   'against',
#   'one',
#   'natur',
#   's',
#   'most',
#   'fearsom',
#   'predat'],
#  ['furthermor',
#   'a',
#   'third',
#   'sabretooth',
#   'more',
#   'danger',
#   'and',
#   'slow',
#   'stalk',
#   'it',
#   'victim',
#   'the',
#   'movi',
#   'deliv',
#   'the',
#   'good',
#   'with',
#   'lot',
#   'of',
#   'blood',
#   'and',
#   'gore',
#   'as',
#   'behead',
#   'hair',
#   'rais',
#   'chill',
#   'full',
#   'of',
#   'scare',
#   'when',
#   'the',
#   'sabretooth',
#   'appear',
#   'with',
#   'mediocr',
#   'special',
#   'effect',
#   'the',
#   'stori',
#   'provid',
#   'excit',
#   'and',
#   'stir',
#   'entertain',
#   'but',
#   'it',
#   'result',
#   'to',
#   'be',
#   'quit',
#   'bore',
#   'the',
#   'giant',
#   'anim',
#   'are',
#   'major',
#   'made',
#   'by',
#   'comput',
#   'generat',
#   'and',
#   'seem',
#   'total',
#   'lousi',
#   'middl',
#   'perform',
#   'though',
#   'the',
#   'player',
#   'react',
#   'appropri',
#   'to',
#   'becom',
#   'food',
#   'actor',
#   'give',
#   'vigor',
#   'physic',
#   'perform',
#   'dodg',
#   'the',
#   'beast',
#   'run',
#   'bound',
#   'and',
#   'leap',
#   'or',
#   'dangl',
#   'over',
#   'wall'],
#  ['and', 'it', 'pack', 'a', 'ridicul', 'final', 'dead', 'scene'],
#  ['no',
#   'for',
#   'small',
#   'kid',
#   'by',
#   'realist',
#   'gori',
#   'and',
#   'violent',
#   'attack',
#   'scene'],
#  ['other',
#   'film',
#   'about',
#   'sabretooth',
#   'or',
#   'smilodon',
#   'are',
#   'the',
#   'follow',
#   'sabretooth',
#   'by',
#   'jame',
#   'r',
#   'hickox',
#   'with',
#   'vanessa',
#   'angel',
#   'david',
#   'keith',
#   'and',
#   'john',
#   'rhys',
#   'davi',
#   'and',
#   'the',
#   'much',
#   'better',
#   'bc',
#   'by',
#   'roland',
#   'emmerich',
#   'with',
#   'with',
#   'steven',
#   'strait',
#   'cliff',
#   'curti',
#   'and',
#   'camilla',
#   'bell'],
#  ['this',
#   'motion',
#   'pictur',
#   'fill',
#   'with',
#   'bloodi',
#   'moment',
#   'is',
#   'bad',
#   'direct',
#   'by',
#   'georg',
#   'miller',
#   'and',
#   'with',
#   'no',
#   'origin',
#   'becaus',
#   'take',
#   'too',
#   'mani',
#   'element',
#   'from',
#   'previous',
#   'film'],
#  ['miller',
#   'is',
#   'an',
#   'australian',
#   'director',
#   'usual',
#   'work',
#   'for',
#   'televis',
#   'tidal',
#   'wave',
#   'journey',
#   'to',
#   'the',
#   'center',
#   'of',
#   'the',
#   'earth',
#   'and',
#   'mani',
#   'other',
#   'and',
#   'occasion',
#   'for',
#   'cinema',
#   'the',
#   'man',
#   'from',
#   'snowi',
#   'river',
#   'zeus',
#   'and',
#   'roxann',
#   'robinson',
#   'cruso'],
#  ['rate', 'below', 'averag', 'bottom', 'of', 'barrel'],
#  ['it',
#   'must',
#   'be',
#   'assum',
#   'that',
#   'those',
#   'who',
#   'prais',
#   'this',
#   'film',
#   'the',
#   'greatest',
#   'film',
#   'opera',
#   'ever',
#   'didn',
#   't',
#   'i',
#   'read',
#   'somewher'],
#  ['either',
#   'don',
#   't',
#   'care',
#   'for',
#   'opera',
#   'don',
#   't',
#   'care',
#   'for',
#   'wagner',
#   'or',
#   'don',
#   't',
#   'care',
#   'about',
#   'anyth',
#   'except',
#   'their',
#   'desir',
#   'to',
#   'appear',
#   'cultur'],
#  ['either',
#   'as',
#   'a',
#   'represent',
#   'of',
#   'wagner',
#   's',
#   'swan',
#   'song',
#   'or',
#   'as',
#   'a',
#   'movi',
#   'this',
#   'strike',
#   'me',
#   'as',
#   'an',
#   'unmitig',
#   'disast',
#   'with',
#   'a',
#   'leaden',
#   'read',
#   'of',
#   'the',
#   'score',
#   'match',
#   'to',
#   'a',
#   'tricksi',
#   'lugubri',
#   'realis',
#   'of',
#   'the',
#   'text',
#   'it',
#   's',
#   'question',
#   'that',
#   'peopl',
#   'with',
#   'idea',
#   'as',
#   'to',
#   'what',
#   'an',
#   'opera',
#   'or',
#   'for',
#   'that',
#   'matter',
#   'a',
#   'play',
#   'especi',
#   'one',
#   'by',
#   'shakespear',
#   'is',
#   'about',
#   'should',
#   'be',
#   'allow',
#   'anywher',
#   'near',
#   'a',
#   'theatr',
#   'or',
#   'film',
#   'studio',
#   'syberberg',
#   'veri',
#   'fashion',
#   'but',
#   'without',
#   'the',
#   'smallest',
#   'justif',
#   'from',
#   'wagner',
#   's',
#   'text',
#   'decid',
#   'that',
#   'parsif',
#   'is',
#   'about',
#   'bisexu',
#   'integr',
#   'so',
#   'that',
#   'the',
#   'titl',
#   'charact',
#   'in',
#   'the',
#   'latter',
#   'stage',
#   'transmut',
#   'into',
#   'a',
#   'kind',
#   'of',
#   'beatnik',
#   'babe',
#   'though',
#   'one',
#   'who',
#   'continu',
#   'to',
#   'sing',
#   'high',
#   'tenor',
#   'few',
#   'if',
#   'ani',
#   'of',
#   'the',
#   'actor',
#   'in',
#   'the',
#   'film',
#   'are',
#   'the',
#   'singer',
#   'and',
#   'we',
#   'get',
#   'a',
#   'doubl',
#   'dose',
#   'of',
#   'armin',
#   'jordan',
#   'the',
#   'conductor',
#   'who',
#   'is',
#   'seen',
#   'as',
#   'the',
#   'face',
#   'but',
#   'not',
#   'heard',
#   'as',
#   'the',
#   'voic',
#   'of',
#   'amforta',
#   'and',
#   'also',
#   'appear',
#   'monstrous',
#   'in',
#   'doubl',
#   'exposur',
#   'as',
#   'a',
#   'kind',
#   'of',
#   'batonzilla',
#   'or',
#   'conductor',
#   'who',
#   'ate',
#   'monsalvat',
#   'dure',
#   'the',
#   'play',
#   'of',
#   'the',
#   'good',
#   'friday',
#   'music',
#   'in',
#   'which',
#   'by',
#   'the',
#   'way',
#   'the',
#   'transcend',
#   'loveli',
#   'of',
#   'natur',
#   'is',
#   'repres',
#   'by',
#   'a',
#   'scatter',
#   'of',
#   'shopworn',
#   'and',
#   'flaccid',
#   'crocus',
#   'stuck',
#   'in',
#   'ill',
#   'laid',
#   'turf',
#   'an',
#   'expedi',
#   'which',
#   'baffl',
#   'me'],
#  ['in',
#   'the',
#   'theatr',
#   'we',
#   'sometim',
#   'have',
#   'to',
#   'piec',
#   'out',
#   'such',
#   'imperfect',
#   'with',
#   'our',
#   'thought',
#   'but',
#   'i',
#   'can',
#   't',
#   'think',
#   'whi',
#   'syberberg',
#   'couldn',
#   't',
#   'splice',
#   'in',
#   'for',
#   'parsif',
#   'and',
#   'gurnemanz',
#   'mountain',
#   'pastur',
#   'as',
#   'lush',
#   'as',
#   'was',
#   'provid',
#   'for',
#   'juli',
#   'andrew',
#   'in',
#   'sound',
#   'of',
#   'music',
#   'the',
#   'sound',
#   'is',
#   'hard',
#   'to',
#   'endur',
#   'the',
#   'high',
#   'voic',
#   'and',
#   'the',
#   'trumpet',
#   'in',
#   'particular',
#   'possess',
#   'an',
#   'aural',
#   'glare',
#   'that',
#   'add',
#   'anoth',
#   'sort',
#   'of',
#   'fatigu',
#   'to',
#   'our',
#   'impati',
#   'with',
#   'the',
#   'uninspir',
#   'conduct',
#   'and',
#   'paralyt',
#   'unfold',
#   'of',
#   'the',
#   'ritual'],
#  ['someon',
#   'in',
#   'anoth',
#   'review',
#   'mention',
#   'the',
#   'bayreuth',
#   'record',
#   'and',
#   'knappertsbusch',
#   'though',
#   'his',
#   'tempi',
#   'are',
#   'often',
#   'veri',
#   'slow',
#   'had',
#   'what',
#   'jordan',
#   'altogeth',
#   'lack',
#   'a',
#   'sens',
#   'of',
#   'puls',
#   'a',
#   'feel',
#   'for',
#   'the',
#   'ebb',
#   'and',
#   'flow',
#   'of',
#   'the',
#   'music',
#   'and',
#   'after',
#   'half',
#   'a',
#   'centuri',
#   'the',
#   'orchestr',
#   'sound',
#   'in',
#   'that',
#   'set',
#   'in',
#   'modern',
#   'press',
#   'is',
#   'still',
#   'superior',
#   'to',
#   'this',
#   'film'],
#  ['superbl',
#   'trashi',
#   'and',
#   'wondrous',
#   'unpretenti',
#   's',
#   'exploit',
#   'hooray'],
#  ['the',
#   'pre',
#   'credit',
#   'open',
#   'sequenc',
#   'somewhat',
#   'give',
#   'the',
#   'fals',
#   'impress',
#   'that',
#   'we',
#   're',
#   'deal',
#   'with',
#   'a',
#   'serious',
#   'and',
#   'harrow',
#   'drama',
#   'but',
#   'you',
#   'need',
#   'not',
#   'fear',
#   'becaus',
#   'bare',
#   'ten',
#   'minut',
#   'later',
#   'we',
#   're',
#   'up',
#   'until',
#   'our',
#   'neck',
#   'in',
#   'nonsens',
#   'chainsaw',
#   'battl',
#   'rough',
#   'fist',
#   'fight',
#   'lurid',
#   'dialog',
#   'and',
#   'gratuit',
#   'nuditi'],
#  ['bo',
#   'and',
#   'ingrid',
#   'are',
#   'two',
#   'orphan',
#   'sibl',
#   'with',
#   'an',
#   'unusu',
#   'close',
#   'and',
#   'even',
#   'slight',
#   'pervert',
#   'relationship'],
#  ['can',
#   'you',
#   'imagin',
#   'play',
#   'rip',
#   'off',
#   'the',
#   'towel',
#   'that',
#   'cover',
#   'your',
#   'sister',
#   's',
#   'nake',
#   'bodi',
#   'and',
#   'then',
#   'stare',
#   'at',
#   'her',
#   'unshaven',
#   'genit',
#   'for',
#   'sever',
#   'whole',
#   'minut'],
#  ['well',
#   'bo',
#   'doe',
#   'that',
#   'to',
#   'his',
#   'sister',
#   'and',
#   'judg',
#   'by',
#   'her',
#   'dub',
#   'laughter',
#   'she',
#   'doesn',
#   't',
#   'mind',
#   'at',
#   'all'],
#  ['sick', 'dude'],
#  ['anyway',
#   'as',
#   'kid',
#   'they',
#   'fled',
#   'from',
#   'russia',
#   'with',
#   'their',
#   'parent',
#   'but',
#   'nasti',
#   'soldier',
#   'brutal',
#   'slaughter',
#   'mommi',
#   'and',
#   'daddi'],
#  ['a',
#   'friend',
#   'smuggler',
#   'took',
#   'custodi',
#   'over',
#   'them',
#   'howev',
#   'and',
#   'even',
#   'rais',
#   'and',
#   'train',
#   'bo',
#   'and',
#   'ingrid',
#   'into',
#   'expert',
#   'smuggler'],
#  ['when',
#   'the',
#   'actual',
#   'plot',
#   'lift',
#   'off',
#   'year',
#   'later',
#   'they',
#   're',
#   'face',
#   'their',
#   'ultim',
#   'quest',
#   'as',
#   'the',
#   'mythic',
#   'and',
#   'incred',
#   'valuabl',
#   'white',
#   'fire',
#   'diamond',
#   'is',
#   'coincident',
#   'found',
#   'in',
#   'a',
#   'mine'],
#  ['veri',
#   'few',
#   'thing',
#   'in',
#   'life',
#   'ever',
#   'made',
#   'as',
#   'littl',
#   'sens',
#   'as',
#   'the',
#   'plot',
#   'and',
#   'narrat',
#   'structur',
#   'of',
#   'white',
#   'fire',
#   'but',
#   'it',
#   'sure',
#   'is',
#   'a',
#   'lot',
#   'of',
#   'fun',
#   'to',
#   'watch'],
#  ['most',
#   'of',
#   'the',
#   'time',
#   'you',
#   'have',
#   'no',
#   'clue',
#   'who',
#   's',
#   'beat',
#   'up',
#   'who',
#   'or',
#   'for',
#   'what',
#   'caus',
#   'and',
#   'i',
#   'bet',
#   'the',
#   'actor',
#   'understood',
#   'even',
#   'less',
#   'but',
#   'whatev'],
#  ['the',
#   'violenc',
#   'is',
#   'magnific',
#   'grotesqu',
#   'and',
#   'everi',
#   'singl',
#   'plot',
#   'twist',
#   'is',
#   'pleas',
#   'retard'],
#  ['the',
#   'script',
#   'goe',
#   'total',
#   'bonker',
#   'beyond',
#   'repair',
#   'when',
#   'sudden',
#   'and',
#   'i',
#   'won',
#   't',
#   'reveal',
#   'for',
#   'what',
#   'reason',
#   'bo',
#   'need',
#   'a',
#   'replac',
#   'for',
#   'ingrid',
#   'and',
#   'fred',
#   'williamson',
#   'enter',
#   'the',
#   'scene',
#   'with',
#   'a',
#   'big',
#   'cigar',
#   'in',
#   'his',
#   'mouth',
#   'and',
#   'his',
#   'sleazi',
#   'black',
#   'finger',
#   'all',
#   'over',
#   'the',
#   'local',
#   'prostitut'],
#  ['bo',
#   's',
#   'princip',
#   'oppon',
#   'is',
#   'an',
#   'italian',
#   'chick',
#   'with',
#   'big',
#   'breast',
#   'but',
#   'a',
#   'hideous',
#   'accent',
#   'the',
#   'preposter',
#   'but',
#   'catchi',
#   'theme',
#   'song',
#   'play',
#   'at',
#   'least',
#   'a',
#   'dozen',
#   'time',
#   'throughout',
#   'the',
#   'film',
#   'there',
#   's',
#   'the',
#   'obligatori',
#   'we',
#   're',
#   'fall',
#   'in',
#   'love',
#   'montag',
#   'and',
#   'load',
#   'of',
#   'other',
#   'attract'],
#  ['my', 'god', 'what', 'a', 'brilliant', 'experi'],
#  ['the',
#   'origin',
#   'french',
#   'titl',
#   'translat',
#   'itself',
#   'as',
#   'life',
#   'to',
#   'surviv',
#   'which',
#   'is',
#   'uniqu',
#   'appropri',
#   'becaus',
#   'it',
#   'make',
#   'just',
#   'as',
#   'much',
#   'sens',
#   'as',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'movi',
#   'none'],
#  ['i',
#   'dont',
#   'know',
#   'whi',
#   'peopl',
#   'think',
#   'this',
#   'is',
#   'such',
#   'a',
#   'bad',
#   'movi'],
#  ['it',
#   'got',
#   'a',
#   'pretti',
#   'good',
#   'plot',
#   'some',
#   'good',
#   'action',
#   'and',
#   'the',
#   'chang',
#   'of',
#   'locat',
#   'for',
#   'harri',
#   'doe',
#   'not',
#   'hurt',
#   'either'],
#  ['sure',
#   'some',
#   'of',
#   'it',
#   'offens',
#   'and',
#   'gratuit',
#   'but',
#   'this',
#   'is',
#   'not',
#   'the',
#   'onli',
#   'movi',
#   'like',
#   'that'],
#  ['eastwood',
#   'is',
#   'in',
#   'good',
#   'form',
#   'as',
#   'dirti',
#   'harri',
#   'and',
#   'i',
#   'like',
#   'pat',
#   'hingl',
#   'in',
#   'this',
#   'movi',
#   'as',
#   'the',
#   'small',
#   'town',
#   'cop'],
#  ['if',
#   'you',
#   'like',
#   'dirti',
#   'harri',
#   'then',
#   'you',
#   'should',
#   'see',
#   'this',
#   'one',
#   'it',
#   'a',
#   'lot',
#   'better',
#   'than',
#   'the',
#   'dead',
#   'pool'],
#  [],
#  ['this',
#   'movi',
#   'could',
#   'have',
#   'been',
#   'veri',
#   'good',
#   'but',
#   'come',
#   'up',
#   'way',
#   'short'],
#  ['cheesi', 'special', 'effect', 'and', 'so', 'so', 'act'],
#  ['i',
#   'could',
#   'have',
#   'look',
#   'past',
#   'that',
#   'if',
#   'the',
#   'stori',
#   'wasn',
#   't',
#   'so',
#   'lousi'],
#  ['if',
#   'there',
#   'was',
#   'more',
#   'of',
#   'a',
#   'background',
#   'stori',
#   'it',
#   'would',
#   'have',
#   'been',
#   'better'],
#  ['the',
#   'plot',
#   'center',
#   'around',
#   'an',
#   'evil',
#   'druid',
#   'witch',
#   'who',
#   'is',
#   'link',
#   'to',
#   'this',
#   'woman',
#   'who',
#   'get',
#   'migrain'],
#  ['the',
#   'movi',
#   'drag',
#   'on',
#   'and',
#   'on',
#   'and',
#   'never',
#   'clear',
#   'explain',
#   'anyth',
#   'it',
#   'just',
#   'keep',
#   'plod',
#   'on'],
#  ['christoph',
#   'walken',
#   'has',
#   'a',
#   'part',
#   'but',
#   'it',
#   'is',
#   'complet',
#   'senseless',
#   'as',
#   'is',
#   'most',
#   'of',
#   'the',
#   'movi'],
#  ['this',
#   'movi',
#   'had',
#   'potenti',
#   'but',
#   'it',
#   'look',
#   'like',
#   'some',
#   'realli',
#   'bad',
#   'made',
#   'for',
#   'tv',
#   'movi'],
#  ['i', 'would', 'avoid', 'this', 'movi'],
#  ['i', 'watch', 'this', 'video', 'at', 'a', 'friend', 's', 'hous'],
#  ['i', 'm', 'glad', 'i', 'did', 'not', 'wast', 'money', 'buy', 'this', 'one'],
#  ['the',
#   'video',
#   'cover',
#   'has',
#   'a',
#   'scene',
#   'from',
#   'the',
#   'movi',
#   'capricorn',
#   'one'],
#  ['the',
#   'movi',
#   'start',
#   'out',
#   'with',
#   'sever',
#   'clip',
#   'of',
#   'rocket',
#   'blow',
#   'up',
#   'most',
#   'not',
#   'relat',
#   'to',
#   'man',
#   'flight'],
#  ['sibrel',
#   's',
#   'smoke',
#   'gun',
#   'is',
#   'a',
#   'short',
#   'video',
#   'clip',
#   'of',
#   'the',
#   'astronaut',
#   'prepar',
#   'a',
#   'video',
#   'broadcast'],
#  ['he',
#   'edit',
#   'in',
#   'his',
#   'own',
#   'voic',
#   'over',
#   'instead',
#   'of',
#   'let',
#   'us',
#   'listen',
#   'to',
#   'what',
#   'the',
#   'crew',
#   'had',
#   'to',
#   'say'],
#  ['the',
#   'video',
#   'curious',
#   'end',
#   'with',
#   'a',
#   'show',
#   'of',
#   'the',
#   'zaprud',
#   'film'],
#  ['his',
#   'claim',
#   'about',
#   'radiat',
#   'shield',
#   'star',
#   'photographi',
#   'and',
#   'other',
#   'lead',
#   'me',
#   'to',
#   'believ',
#   'is',
#   'he',
#   'extrem',
#   'ignor',
#   'or',
#   'has',
#   'some',
#   'sort',
#   'of',
#   'ax',
#   'to',
#   'grind',
#   'against',
#   'nasa',
#   'the',
#   'astronaut',
#   'or',
#   'american',
#   'in',
#   'general'],
#  ['his', 'scienc', 'is', 'bad', 'and', 'so', 'is', 'this', 'video'],
#  ['a',
#   'friend',
#   'of',
#   'mine',
#   'bought',
#   'this',
#   'film',
#   'for',
#   'and',
#   'even',
#   'then',
#   'it',
#   'was',
#   'grossli',
#   'overpr'],
#  ['despit',
#   'featur',
#   'big',
#   'name',
#   'such',
#   'as',
#   'adam',
#   'sandler',
#   'billi',
#   'bob',
#   'thornton',
#   'and',
#   'the',
#   'incred',
#   'talent',
#   'burt',
#   'young',
#   'this',
#   'film',
#   'was',
#   'about',
#   'as',
#   'funni',
#   'as',
#   'take',
#   'a',
#   'chisel',
#   'and',
#   'hammer',
#   'it',
#   'straight',
#   'through',
#   'your',
#   'earhol'],
#  ['it',
#   'use',
#   'tire',
#   'bottom',
#   'of',
#   'the',
#   'barrel',
#   'comed',
#   'techniqu',
#   'consist',
#   'break',
#   'the',
#   'fourth',
#   'wall',
#   'as',
#   'sandler',
#   'talk',
#   'to',
#   'the',
#   'audienc',
#   'and',
#   'seem',
#   'pointless',
#   'montag',
#   'of',
#   'hot',
#   'girl',
#   'adam',
#   'sandler',
#   'play',
#   'a',
#   'waiter',
#   'on',
#   'a',
#   'cruis',
#   'ship',
#   'who',
#   'want',
#   'to',
#   'make',
#   'it',
#   'as',
#   'a',
#   'success',
#   'comedian',
#   'in',
#   'order',
#   'to',
#   'becom',
#   'success',
#   'with',
#   'women'],
#  ['when',
#   'the',
#   'ship',
#   's',
#   'resid',
#   'comedian',
#   'the',
#   'shameless',
#   'name',
#   'dicki',
#   'due',
#   'to',
#   'his',
#   'unfathom',
#   'success',
#   'with',
#   'the',
#   'opposit',
#   'gender',
#   'is',
#   'presum',
#   'lost',
#   'at',
#   'sea',
#   'sandler',
#   's',
#   'charact',
#   'shecker',
#   'get',
#   'his',
#   'big',
#   'break'],
#  ['dicki',
#   'is',
#   'not',
#   'dead',
#   'he',
#   's',
#   'rather',
#   'lock',
#   'in',
#   'the',
#   'bathroom',
#   'presum',
#   'sea',
#   'sick',
#   'perhap',
#   'from',
#   'his',
#   'mouth',
#   'he',
#   'just',
#   'vomit',
#   'the',
#   'worst',
#   'film',
#   'of',
#   'all',
#   'time'],
#  ['this', 'movi', 'is', 'full', 'of', 'refer'],
#  ['like', 'mad', 'max', 'ii', 'the', 'wild', 'one', 'and', 'mani', 'other'],
#  ['the',
#   'ladybug',
#   's',
#   'face',
#   'it',
#   's',
#   'a',
#   'clear',
#   'refer',
#   'or',
#   'tribut',
#   'to',
#   'peter',
#   'lorr'],
#  ['this', 'movi', 'is', 'a', 'masterpiec'],
#  ['we', 'll', 'talk', 'much', 'more', 'about', 'in', 'the', 'futur'],
#  ['what',
#   'happen',
#   'when',
#   'an',
#   'armi',
#   'of',
#   'wetback',
#   'towelhead',
#   'and',
#   'godless',
#   'eastern',
#   'european',
#   'commi',
#   'gather',
#   'their',
#   'forc',
#   'south',
#   'of',
#   'the',
#   'border'],
#  ['gari', 'busey', 'kick', 'their', 'butt', 'of', 'cours'],
#  ['anoth',
#   'laughabl',
#   'exampl',
#   'of',
#   'reagan',
#   'era',
#   'cultur',
#   'fallout',
#   'bulletproof',
#   'wast',
#   'a',
#   'decent',
#   'support',
#   'cast',
#   'head',
#   'by',
#   'l',
#   'q',
#   'jone',
#   'and',
#   'thalmus',
#   'rasulala'],
#  ['although',
#   'i',
#   'general',
#   'do',
#   'not',
#   'like',
#   'remak',
#   'believ',
#   'that',
#   'remak',
#   'are',
#   'wast',
#   'of',
#   'time',
#   'this',
#   'film',
#   'is',
#   'an',
#   'except'],
#  ['i',
#   'didn',
#   't',
#   'actual',
#   'know',
#   'so',
#   'far',
#   'until',
#   'read',
#   'the',
#   'previous',
#   'comment',
#   'that',
#   'this',
#   'was',
#   'a',
#   'remak',
#   'so',
#   'my',
#   'opinion',
#   'is',
#   'pure',
#   'about',
#   'the',
#   'actual',
#   'film',
#   'and',
#   'not',
#   'a',
#   'comparison',
#   'the',
#   'stori',
#   'and',
#   'the',
#   'way',
#   'it',
#   'is',
#   'written',
#   'is',
#   'no',
#   'question',
#   'it',
#   'is',
#   'capot'],
#  ['there',
#   'is',
#   'no',
#   'need',
#   'for',
#   'more',
#   'word',
#   'the',
#   'play',
#   'of',
#   'anthoni',
#   'edward',
#   'and',
#   'eric',
#   'robert',
#   'is',
#   'superb'],
#  ['i',
#   'have',
#   'seen',
#   'some',
#   'movi',
#   'with',
#   'them',
#   'each',
#   'in',
#   'one',
#   'or',
#   'the',
#   'other'],
#  ['i',
#   'was',
#   'certain',
#   'that',
#   'they',
#   'are',
#   'good',
#   'actor',
#   'and',
#   'in',
#   'case',
#   'of',
#   'eric',
#   'i',
#   'alway',
#   'wonder',
#   'whi',
#   'his',
#   'sister',
#   'is',
#   'the',
#   'number',
#   'famous',
#   'star',
#   'and',
#   'not',
#   'her',
#   'brother'],
#  ['this',
#   'time',
#   'this',
#   'certainti',
#   'is',
#   'rais',
#   'to',
#   'fact',
#   'no',
#   'question'],
#  ['his',
#   'play',
#   'just',
#   'as',
#   'well',
#   'as',
#   'the',
#   'play',
#   'of',
#   'mr',
#   'edward',
#   'is',
#   'clear',
#   'the',
#   'top',
#   'of',
#   'all',
#   'their',
#   'profess',
#   'i',
#   'recommend',
#   'this',
#   'film',
#   'to',
#   'be',
#   'on',
#   'your',
#   'top',
#   'film',
#   'to',
#   'see',
#   'and',
#   'keep',
#   'on',
#   'your',
#   'dvd',
#   'shelv'],
#  ['mr',
#   'harvey',
#   'light',
#   'a',
#   'candl',
#   'is',
#   'anchor',
#   'by',
#   'a',
#   'brilliant',
#   'perform',
#   'by',
#   'timothi',
#   'spall',
#   'while',
#   'we',
#   'can',
#   'predict',
#   'that',
#   'his',
#   'titular',
#   'moros',
#   'up',
#   'tight',
#   'teacher',
#   'will',
#   'have',
#   'some',
#   'sort',
#   'of',
#   'break',
#   'down',
#   'or',
#   'catharsi',
#   'base',
#   'on',
#   'some',
#   'deep',
#   'down',
#   'secret',
#   'from',
#   'his',
#   'past',
#   'how',
#   'his',
#   'emot',
#   'are',
#   'unveil',
#   'is',
#   'surpris'],
#  ['spall',
#   's',
#   'rang',
#   'of',
#   'feel',
#   'convey',
#   'is',
#   'quit',
#   'move',
#   'and',
#   'more',
#   'than',
#   'he',
#   'usual',
#   'get',
#   'to',
#   'portray',
#   'as',
#   'part',
#   'of',
#   'the',
#   'mike',
#   'leigh',
#   'repertori',
#   'while',
#   'an',
#   'expect',
#   'bore',
#   'school',
#   'bus',
#   'trip',
#   'has',
#   'onli',
#   'been',
#   'use',
#   'for',
#   'comic',
#   'purpos',
#   'such',
#   'as',
#   'on',
#   'the',
#   'simpson',
#   'this',
#   'central',
#   'situat',
#   'of',
#   'a',
#   'visit',
#   'to',
#   'salisburi',
#   'cathedr',
#   'in',
#   'rhidian',
#   'brook',
#   's',
#   'script',
#   'is',
#   'well',
#   'contain',
#   'and',
#   'structur',
#   'for',
#   'dramat',
#   'purpos',
#   'and',
#   'is',
#   'almost',
#   'formal',
#   'divid',
#   'into',
#   'act',
#   'we',
#   're',
#   'introduc',
#   'to',
#   'the',
#   'urban',
#   'british',
#   'rang',
#   'of',
#   'racial',
#   'and',
#   'religi',
#   'divers',
#   'kid',
#   'with',
#   'their',
#   'uniform',
#   'i',
#   'couldn',
#   't',
#   'tell',
#   'if',
#   'this',
#   'is',
#   'a',
#   'privat',
#   'or',
#   'public',
#   'school',
#   'as',
#   'they',
#   'gather',
#   'the',
#   'rap',
#   'black',
#   'kid',
#   'the',
#   'serious',
#   'south',
#   'asian',
#   'and',
#   'muslim',
#   'the',
#   'white',
#   'bulli',
#   'and',
#   'mean',
#   'girl',
#   'but',
#   'convey',
#   'quit',
#   'natur',
#   'and',
#   'individu'],
#  ['the',
#   'young',
#   'actor',
#   'some',
#   'of',
#   'whom',
#   'i',
#   'recogn',
#   'from',
#   'british',
#   'tv',
#   'such',
#   'as',
#   'shameless',
#   'were',
#   'exuber',
#   'in',
#   'repres',
#   'the',
#   'usual',
#   'rang',
#   'of',
#   'junior',
#   'high',
#   'social',
#   'pressur'],
#  ['celia',
#   'imri',
#   'put',
#   'more',
#   'warmth',
#   'into',
#   'the',
#   'supervisor',
#   's',
#   'role',
#   'than',
#   'the',
#   'martinet',
#   'she',
#   'usual',
#   'has',
#   'to',
#   'play',
#   'a',
#   'break',
#   'in',
#   'the',
#   'trip',
#   'lead',
#   'to',
#   'a',
#   'transform',
#   'crisi',
#   'for',
#   'some',
#   'while',
#   'other',
#   'remain',
#   'amus',
#   'oblivi'],
#  ['we',
#   'think',
#   'like',
#   'the',
#   'teacher',
#   'portray',
#   'by',
#   'ben',
#   'mile',
#   'of',
#   'coupl',
#   'that',
#   'we',
#   'will',
#   'be',
#   'spoon',
#   'fed',
#   'a',
#   'didact',
#   'lesson',
#   'about',
#   'religi',
#   'toler',
#   'but',
#   'it',
#   's',
#   'much',
#   'more',
#   'about',
#   'faith',
#   'in',
#   'peopl',
#   'as',
#   'well',
#   'as',
#   'god',
#   'which',
#   'is',
#   'whi',
#   'the',
#   'bbc',
#   'show',
#   'it',
#   'in',
#   'england',
#   'at',
#   'easter',
#   'time',
#   'and',
#   'bbc',
#   'america',
#   'show',
#   'it',
#   'in',
#   'the',
#   'u',
#   's',
#   'over',
#   'christma',
#   'nathali',
#   'press',
#   'who',
#   'was',
#   'also',
#   'so',
#   'good',
#   'in',
#   'summer',
#   'of',
#   'love',
#   'has',
#   'a',
#   'key',
#   'role',
#   'in',
#   'mr',
#   'harvey',
#   's',
#   'redempt',
#   'that',
#   'could',
#   'have',
#   'been',
#   'play',
#   'for',
#   'movi',
#   'of',
#   'the',
#   'week',
#   'preach',
#   'but',
#   'is',
#   'touch',
#   'as',
#   'they',
#   'reach',
#   'out',
#   'to',
#   'each',
#   'other',
#   'in',
#   'an',
#   'unexpect',
#   'way',
#   'unfortun',
#   'i',
#   'saw',
#   'their',
#   'intens',
#   'scene',
#   'interrupt',
#   'by',
#   'commerci',
#   'while',
#   'it',
#   'is',
#   'a',
#   'bit',
#   'heavi',
#   'hand',
#   'in',
#   'sever',
#   'time',
#   'point',
#   'call',
#   'this',
#   'road',
#   'trip',
#   'a',
#   'pilgrimag',
#   'this',
#   'quiet',
#   'film',
#   'was',
#   'the',
#   'best',
#   'evoc',
#   'of',
#   'good',
#   'will',
#   'toward',
#   'men',
#   'than',
#   'i',
#   've',
#   'seen',
#   'in',
#   'most',
#   'holiday',
#   'theme',
#   'tv',
#   'movi'],
#  ['i',
#   'had',
#   'a',
#   'feel',
#   'that',
#   'after',
#   'submerg',
#   'this',
#   'one',
#   'wouldn',
#   't',
#   'be',
#   'ani',
#   'better'],
#  ['i', 'was', 'right'],
#  ['he',
#   'must',
#   'be',
#   'look',
#   'for',
#   'champagn',
#   'money',
#   'and',
#   'not',
#   'care',
#   'about',
#   'the',
#   'final',
#   'product',
#   'his',
#   'voic',
#   'get',
#   'repeat',
#   'dub',
#   'over',
#   'by',
#   'a',
#   'stranger',
#   'that',
#   'sound',
#   'noth',
#   'like',
#   'him',
#   'the',
#   'edit',
#   'is',
#   'well',
#   'just',
#   'a',
#   'grade',
#   'abov',
#   'amateurish'],
#  ['it',
#   's',
#   'noth',
#   'more',
#   'than',
#   'a',
#   'b',
#   'or',
#   'c',
#   'grade',
#   'movi',
#   'with',
#   'just',
#   'enough',
#   'money',
#   'to',
#   'hire',
#   'a',
#   'coupl',
#   'talent',
#   'cameramen',
#   'and',
#   'an',
#   'ok',
#   'sound',
#   'design',
#   'like',
#   'the',
#   'previous',
#   'poster',
#   'said',
#   'the',
#   'problem',
#   'seem',
#   'to',
#   'appear',
#   'in',
#   'post',
#   'product',
#   'voic',
#   'dub',
#   'etc'],
#  ['too',
#   'bad',
#   'caus',
#   'the',
#   'plot',
#   's',
#   'actual',
#   'ok',
#   'for',
#   'a',
#   'sg',
#   'flick',
#   'i',
#   'll',
#   'never',
#   'rent',
#   'anoth',
#   'sg',
#   'flick',
#   'unless',
#   'he',
#   'email',
#   'me',
#   'ask',
#   'for',
#   'forgiv',
#   'too',
#   'bad',
#   'i',
#   'miss',
#   'kelli',
#   'lebrock',
#   'jimbo'],
#  ['note',
#   'to',
#   'georg',
#   'litman',
#   'and',
#   'other',
#   'the',
#   'mysteri',
#   'scienc',
#   'theater',
#   'riff',
#   'is',
#   'i',
#   'don',
#   't',
#   'think',
#   'so',
#   'breeder',
#   'my',
#   'favorit',
#   'riff',
#   'is',
#   'whi',
#   'were',
#   'you',
#   'look',
#   'at',
#   'his',
#   'like',
#   'simpli',
#   'for',
#   'the',
#   'complet',
#   'absurd'],
#  ['that',
#   'and',
#   'right',
#   'well',
#   'did',
#   'not',
#   'over',
#   'all',
#   'i',
#   'would',
#   'say',
#   'we',
#   'must',
#   'give',
#   'credit',
#   'to',
#   'the',
#   'mst',
#   'k',
#   'crew',
#   'for',
#   'tri',
#   'to',
#   'ridicul',
#   'this',
#   'tv',
#   'movi'],
#  ['you',
#   'realli',
#   'can',
#   't',
#   'make',
#   'much',
#   'fun',
#   'of',
#   'the',
#   'dialog',
#   'bill',
#   's',
#   'was',
#   'a',
#   'good',
#   'playwright'],
#  ['on',
#   'the',
#   'other',
#   'hand',
#   'this',
#   'product',
#   'is',
#   'so',
#   'bad',
#   'that',
#   'even',
#   'he',
#   'would',
#   'disown',
#   'it'],
#  ['a',
#   'junior',
#   'high',
#   'school',
#   'drama',
#   'club',
#   'could',
#   'do',
#   'better',
#   'i',
#   'would',
#   'recommend',
#   'that',
#   'you',
#   'buy',
#   'a',
#   'book',
#   'and',
#   'read',
#   'hamlet'],
#  ['stephen',
#   'king',
#   'adapt',
#   'script',
#   'by',
#   'king',
#   'himself',
#   'in',
#   'which',
#   'a',
#   'young',
#   'famili',
#   'newcom',
#   'to',
#   'rural',
#   'main',
#   'find',
#   'out',
#   'about',
#   'the',
#   'pet',
#   'cemeteri',
#   'close',
#   'to',
#   'their',
#   'home'],
#  ['the',
#   'father',
#   'dale',
#   'midkiff',
#   'then',
#   'find',
#   'out',
#   'about',
#   'the',
#   'micmac',
#   'burial',
#   'ground',
#   'beyond',
#   'the',
#   'pet',
#   'cemeteri',
#   'that',
#   'has',
#   'power',
#   'of',
#   'resurrect',
#   'onli',
#   'of',
#   'cours',
#   'anyth',
#   'buri',
#   'there',
#   'come',
#   'back',
#   'not',
#   'quit',
#   'right',
#   'below',
#   'averag',
#   'horror',
#   'pictur',
#   'start',
#   'out',
#   'clumsi',
#   'insult',
#   'and',
#   'inept',
#   'and',
#   'continu',
#   'that',
#   'way',
#   'for',
#   'a',
#   'while',
#   'with',
#   'the',
#   'absolut',
#   'worst',
#   'element',
#   'be',
#   'midkiff',
#   's',
#   'worthless',
#   'perform'],
#  ['it',
#   'get',
#   'a',
#   'littl',
#   'better',
#   'toward',
#   'the',
#   'end',
#   'with',
#   'genuin',
#   'disturb',
#   'final'],
#  ['in',
#   'point',
#   'of',
#   'fact',
#   'the',
#   'whole',
#   'movi',
#   'is',
#   'realli',
#   'disturb',
#   'which',
#   'is',
#   'whi',
#   'i',
#   'can',
#   't',
#   'complet',
#   'dismiss',
#   'it',
#   'at',
#   'least',
#   'it',
#   'has',
#   'someth',
#   'to',
#   'make',
#   'it',
#   'memor'],
#  ['decent',
#   'support',
#   'perform',
#   'by',
#   'fred',
#   'gwynn',
#   'as',
#   'the',
#   'wise',
#   'old',
#   'age',
#   'neighbor',
#   'and',
#   'brad',
#   'greenquist',
#   'as',
#   'the',
#   'disfigur',
#   'spirit',
#   'victor',
#   'pascow',
#   'are',
#   'not',
#   'enough',
#   'to',
#   'realli',
#   'redeem',
#   'film',
#   'king',
#   'has',
#   'his',
#   'usual',
#   'cameo',
#   'as',
#   'the',
#   'minist',
#   'follow',
#   'by',
#   'a',
#   'sequel',
#   'also',
#   'direct',
#   'by',
#   'mari',
#   'lambert',
#   'is',
#   'it',
#   'ani',
#   'wonder',
#   'that',
#   'she',
#   's',
#   'had',
#   'no',
#   'mainstream',
#   'film',
#   'work',
#   'sinc'],
#  [],
#  ['the',
#   'matrix',
#   'was',
#   'an',
#   'excit',
#   'summer',
#   'blockbust',
#   'that',
#   'was',
#   'visual',
#   'fantast',
#   'but',
#   'also',
#   'curious',
#   'thought',
#   'provok',
#   'in',
#   'it',
#   'twilight',
#   'zone',
#   'ish',
#   'manner'],
#  ['the',
#   'general',
#   'rule',
#   'appli',
#   'here',
#   'and',
#   'this',
#   'sequel',
#   'doesn',
#   't',
#   'match',
#   'up',
#   'to',
#   'it',
#   'predecessor'],
#  ['wors',
#   'than',
#   'that',
#   'it',
#   'doesn',
#   't',
#   'even',
#   'compar',
#   'with',
#   'it',
#   'reload',
#   'explod',
#   'onto',
#   'the',
#   'screen',
#   'in',
#   'the',
#   'most',
#   'un',
#   'profession',
#   'fashion'],
#  ['in',
#   'the',
#   'open',
#   'few',
#   'second',
#   'the',
#   'first',
#   'impress',
#   'is',
#   'a',
#   'general',
#   'good',
#   'one',
#   'as',
#   'triniti',
#   'is',
#   'shot',
#   'in',
#   'a',
#   'dream'],
#  ['immedi', 'after', 'that', 'the', 'film', 'nose', 'dive'],
#  ['after',
#   'a',
#   'disastr',
#   'first',
#   'minut',
#   'it',
#   'gradual',
#   'gain',
#   'momentum',
#   'when',
#   'they',
#   'enter',
#   'the',
#   'matrix',
#   'and',
#   'the',
#   'agent',
#   'smith',
#   'battl',
#   'take',
#   'place'],
#  ['but',
#   'it',
#   'lose',
#   'itself',
#   'all',
#   'speed',
#   'when',
#   'it',
#   'reach',
#   'the',
#   'minut',
#   'car',
#   'chase',
#   'sequenc',
#   'and',
#   'get',
#   'even',
#   'wors',
#   'at',
#   'the',
#   'big',
#   'groan',
#   'worthi',
#   'twist',
#   'at',
#   'the',
#   'end'],
#  ['worst', 'of', 'all', 'is', 'the', 'overlong', 'zion', 'rave', 'scene'],
#  ['not',
#   'onli',
#   'doe',
#   'it',
#   'have',
#   'absolut',
#   'noth',
#   'to',
#   'do',
#   'with',
#   'the',
#   'plot',
#   'but',
#   'it',
#   's',
#   'also',
#   'a',
#   'pathet',
#   'excus',
#   'for',
#   'porn',
#   'and',
#   'depress',
#   'danc',
#   'music',
#   'the',
#   'bullet',
#   'time',
#   'aspect',
#   'of',
#   'the',
#   'matrix',
#   'was',
#   'a',
#   'good',
#   'addit',
#   'but',
#   'in',
#   'reload',
#   'they',
#   'overus',
#   'to',
#   'make',
#   'it',
#   'seem',
#   'bore'],
#  ['in',
#   'the',
#   'first',
#   'one',
#   'there',
#   'were',
#   'interest',
#   'plot',
#   'turn',
#   'but',
#   'here',
#   'it',
#   'is',
#   'too',
#   'linear',
#   'to',
#   'be',
#   'remot',
#   'interest'],
#  ['the',
#   'movi',
#   'is',
#   'basic',
#   'just',
#   'a',
#   'seri',
#   'of',
#   'stylish',
#   'divers',
#   'that',
#   'prevent',
#   'us',
#   'from',
#   'realis',
#   'just',
#   'how',
#   'empti',
#   'it',
#   'realli',
#   'is'],
#  ['it',
#   'work',
#   'on',
#   'the',
#   'incorrect',
#   'principl',
#   'that',
#   'bigger',
#   'is',
#   'better'],
#  ['it',
#   'appear',
#   'that',
#   'the',
#   'matrix',
#   'franchis',
#   'has',
#   'quick',
#   'descend',
#   'into',
#   'the',
#   'special',
#   'effect',
#   'drench',
#   'misfir',
#   'that',
#   'other',
#   'franchis',
#   'such',
#   'as',
#   'the',
#   'star',
#   'war',
#   'saga',
#   'have',
#   'the',
#   'act',
#   'standard',
#   'is',
#   'poor',
#   'for',
#   'the',
#   'most',
#   'part'],
#  ['the',
#   'best',
#   'charact',
#   'of',
#   'cours',
#   'goe',
#   'to',
#   'hugo',
#   'weav',
#   's',
#   'agent',
#   'smith',
#   'the',
#   'onli',
#   'one',
#   'to',
#   'be',
#   'slight',
#   'interest'],
#  ['keanu',
#   'reev',
#   'is',
#   'the',
#   'definit',
#   'neo',
#   'but',
#   'in',
#   'all',
#   'the',
#   'special',
#   'effect',
#   'there',
#   'is',
#   'littl',
#   'room',
#   'to',
#   'make',
#   'much',
#   'of',
#   'an',
#   'impact'],
#  ['academi',
#   'award',
#   'nomine',
#   'laurenc',
#   'fishburn',
#   'is',
#   'reduc',
#   'to',
#   'a',
#   'monoton',
#   'mentor',
#   'with',
#   'poor',
#   'dialogu'],
#  ['carri',
#   'ann',
#   'moss',
#   'part',
#   'as',
#   'the',
#   'action',
#   'chick',
#   'could',
#   'have',
#   'been',
#   'done',
#   'much',
#   'better',
#   'by',
#   'ani',
#   'other',
#   'actress'],
#  ['a',
#   'poor',
#   'thrown',
#   'togeth',
#   'movi',
#   'the',
#   'matrix',
#   'reload',
#   'is',
#   'a',
#   'disappoint'],
#  ['those',
#   'who',
#   'didn',
#   't',
#   'like',
#   'the',
#   'first',
#   'one',
#   'are',
#   'unlik',
#   'to',
#   'flock',
#   'to',
#   'it'],
#  ['this', 'one', 's', 'for', 'die', 'hard', 'fan', 'onli'],
#  ['even',
#   'in',
#   'the',
#   'movi',
#   's',
#   'own',
#   'sub',
#   'genr',
#   'of',
#   'special',
#   'effect',
#   'bonanza',
#   'minor',
#   'report',
#   'the',
#   'matrix',
#   'etc'],
#  ['this', 'is', 'still', 'rather', 'poor'],
#  ['my', 'imdb', 'rate'],
#  ['ulli',
#   'lommel',
#   's',
#   'film',
#   'the',
#   'boogey',
#   'man',
#   'is',
#   'no',
#   'classic',
#   'but',
#   'it',
#   's',
#   'an',
#   'abov',
#   'averag',
#   'low',
#   'budget',
#   'chiller',
#   'that',
#   's',
#   'worth',
#   'a',
#   'look'],
#  ['the',
#   'sequel',
#   's',
#   'boogey',
#   'man',
#   'ii',
#   'is',
#   'ultim',
#   'a',
#   'wast',
#   'of',
#   'time',
#   'but',
#   'at',
#   'the',
#   'veri',
#   'least',
#   'it',
#   's',
#   'an',
#   'entertain',
#   'one',
#   'if',
#   'not',
#   'taken',
#   'the',
#   'least',
#   'bit',
#   'serious'],
#  ['now',
#   'ii',
#   'left',
#   'the',
#   'door',
#   'open',
#   'for',
#   'anoth',
#   'sequel',
#   'and',
#   'i',
#   'for',
#   'one',
#   'wouldn',
#   't',
#   'have',
#   'mind',
#   'see',
#   'at',
#   'least',
#   'one',
#   'more'],
#  ['one',
#   'day',
#   'while',
#   'i',
#   'was',
#   'brows',
#   'though',
#   'the',
#   'video',
#   'at',
#   'a',
#   'store',
#   'in',
#   'the',
#   'mall',
#   'i',
#   'came',
#   'across',
#   'a',
#   'film',
#   'entitl',
#   'return',
#   'of',
#   'the',
#   'boogey',
#   'man'],
#  ['when',
#   'i',
#   'found',
#   'out',
#   'it',
#   'was',
#   'a',
#   'sequel',
#   'to',
#   'the',
#   'earlier',
#   'film',
#   'i',
#   'was',
#   'happi',
#   'to',
#   'shell',
#   'out',
#   'a',
#   'few',
#   'buck',
#   'for',
#   'it',
#   'i',
#   'should',
#   'have',
#   'known',
#   'better'],
#  ['though',
#   'the',
#   'open',
#   'titl',
#   'is',
#   'boogey',
#   'man',
#   'this',
#   'is',
#   'no',
#   'sequel',
#   'to',
#   'those',
#   'two',
#   'far',
#   'superior',
#   'film',
#   'i',
#   'name',
#   'abov'],
#  ['well', 'not', 'total', 'anyway', 'pros', 'ha'],
#  ['that', 's', 'a', 'laugh'],
#  ['is',
#   'there',
#   'anyth',
#   'good',
#   'about',
#   'this',
#   'hunk',
#   'of',
#   'cow',
#   'dung'],
#  ['let',
#   's',
#   'see',
#   'it',
#   'has',
#   'footag',
#   'from',
#   'the',
#   'boogey',
#   'man',
#   'and',
#   'um',
#   'it',
#   's',
#   'merci',
#   'short'],
#  ['yeah', 'that', 's', 'about', 'it', 'con', 'where', 'to', 'start'],
#  ['decis', 'decis'],
#  ['first', 'of', 'all', 'this', 'movi', 'is', 'a', 'total', 'bore'],
#  ['it',
#   'goe',
#   'from',
#   'one',
#   'scene',
#   'to',
#   'the',
#   'next',
#   'without',
#   'anyth',
#   'remot',
#   'interest',
#   'or',
#   'scari',
#   'happen'],
#  ['the', 'act', 'is', 'stiff', 'at', 'best'],
#  ['the',
#   'actor',
#   'are',
#   'most',
#   'like',
#   'friend',
#   'of',
#   'the',
#   'director',
#   'who',
#   'had',
#   'no',
#   'act',
#   'experi',
#   'whatsoev',
#   'befor',
#   'and',
#   'probabl',
#   'none',
#   'sinc'],
#  ['the', 'plot', 'is', 'nonexist', 'and', 'script', 'shoddili', 'written'],
#  ['the', 'direct', 'is', 'just', 'plain', 'aw'],
#  ['the',
#   'director',
#   'tri',
#   'to',
#   'make',
#   'the',
#   'film',
#   'look',
#   'all',
#   'artsi',
#   'fartsi',
#   'by',
#   'make',
#   'the',
#   'camera',
#   'move',
#   'around',
#   'light',
#   'flicker',
#   'and',
#   'with',
#   'filter',
#   'but',
#   'it',
#   'add',
#   'noth'],
#  ['the', 'music', 'is', 'dull', 'and', 'hard', 'to', 'hear', 'in', 'part'],
#  ['tie', 'to', 'the', 'origin', 'are', 'botch'],
#  ['suzanna', 'love', 's', 'charact', 'was', 'name', 'lacey', 'not', 'natali'],
#  ['and',
#   'the',
#   'event',
#   'depict',
#   'in',
#   'the',
#   'begin',
#   'of',
#   'the',
#   'origin',
#   'did',
#   'not',
#   'take',
#   'place',
#   'in'],
#  ['also',
#   'if',
#   'this',
#   'has',
#   'a',
#   'in',
#   'the',
#   'titl',
#   'whi',
#   'is',
#   'there',
#   'no',
#   'mention',
#   'of',
#   'what',
#   'happen',
#   'in',
#   'ii'],
#  ['final',
#   'this',
#   'add',
#   'noth',
#   'new',
#   'or',
#   'interest',
#   'to',
#   'either',
#   'the',
#   'seri',
#   'or',
#   'the',
#   'genr',
#   'final',
#   'thought',
#   'the',
#   'peopl',
#   'behind',
#   'this',
#   'wast',
#   'of',
#   'time',
#   'and',
#   'money',
#   'should',
#   'be',
#   'asham',
#   'of',
#   'themselv'],
#  ['it',
#   's',
#   'one',
#   'thing',
#   'if',
#   'that',
#   'had',
#   'been',
#   'an',
#   'origin',
#   'film',
#   'that',
#   'was',
#   'the',
#   'director',
#   's',
#   'first',
#   'and',
#   'suck'],
#  ['but',
#   'instead',
#   'it',
#   's',
#   'suppos',
#   'to',
#   'be',
#   'a',
#   'sequel',
#   'to',
#   'film',
#   'that',
#   'is',
#   'no',
#   'masterpiec',
#   'but',
#   'is',
#   'damn',
#   'sure',
#   'far',
#   'more',
#   'interest',
#   'and',
#   'entertain',
#   'than',
#   'this'],
#  ['if',
#   'there',
#   'ever',
#   'is',
#   'anoth',
#   'sequel',
#   'which',
#   'i',
#   'doubt',
#   'it',
#   'then',
#   'it',
#   'need',
#   'to',
#   'forget',
#   'this',
#   'one',
#   'ever',
#   'happen',
#   'and',
#   'be',
#   'handl',
#   'either',
#   'by',
#   'lommel',
#   'himself',
#   'or',
#   'someon',
#   'who',
#   'has',
#   'at',
#   'least',
#   'some',
#   'idea',
#   'of',
#   'how',
#   'to',
#   'make',
#   'a',
#   'decent',
#   'horror',
#   'film',
#   'my',
#   'rate'],
#  ['this',
#   'movi',
#   'is',
#   'one',
#   'among',
#   'the',
#   'veri',
#   'few',
#   'indian',
#   'movi',
#   'that',
#   'would',
#   'never',
#   'fade',
#   'away',
#   'with',
#   'the',
#   'passag',
#   'of',
#   'time',
#   'nor',
#   'would',
#   'it',
#   'spell',
#   'bind',
#   'appeal',
#   'ever',
#   'diminish',
#   'even',
#   'as',
#   'the',
#   'indian',
#   'cinema',
#   'transform',
#   'into',
#   'the',
#   'abyss',
#   'of',
#   'artifici',
#   'style',
#   'pop',
#   'cultur',
#   'while',
#   'drill',
#   'orient',
#   'extra',
#   'take',
#   'to',
#   'enhanc',
#   'the',
#   'p',
#   't'],
#  ['style',
#   'film',
#   'song',
#   'the',
#   'cinematographi',
#   'speak',
#   'of',
#   'the',
#   'excel',
#   'skill',
#   'of',
#   'josef',
#   'werch',
#   'that',
#   'accentu',
#   'the',
#   'monument',
#   'and',
#   'cinema',
#   'scope',
#   'effect',
#   'of',
#   'the',
#   'film',
#   'in',
#   'it',
#   'entireti',
#   'gone',
#   'are',
#   'the',
#   'day',
#   'of',
#   'great',
#   'cinema',
#   'when',
#   'everi',
#   'scene',
#   'had',
#   'to',
#   'be',
#   'clip',
#   'mani',
#   'time',
#   'and',
#   'retak',
#   'taken',
#   'befor',
#   'final',
#   'it',
#   'while',
#   'meticul',
#   'attent',
#   'was',
#   'paid',
#   'in',
#   'craft',
#   'and',
#   'edit',
#   'the',
#   'scene'],
#  ['some',
#   'of',
#   'it',
#   'poignant',
#   'scene',
#   'are',
#   'fill',
#   'with',
#   'sublim',
#   'emot',
#   'intens',
#   'like',
#   'the',
#   'instanc',
#   'when',
#   'meena',
#   'kumari',
#   'refus',
#   'to',
#   'say',
#   'yes',
#   'as',
#   'an',
#   'approv',
#   'for',
#   'nikah',
#   'marriag',
#   'bond',
#   'and',
#   'climb',
#   'down',
#   'the',
#   'hill',
#   'while',
#   'run',
#   'berserk',
#   'in',
#   'traumat',
#   'frenzi'],
#  ['at',
#   'the',
#   'moment',
#   'raj',
#   'kumar',
#   'follow',
#   'her',
#   'and',
#   'a',
#   'strong',
#   'gale',
#   'of',
#   'wind',
#   'blew',
#   'away',
#   'the',
#   'veil',
#   'of',
#   'kumari',
#   'and',
#   'onto',
#   'the',
#   'leg',
#   'of',
#   'kumar',
#   'kamal',
#   'amrohi',
#   'shall',
#   'alway',
#   'be',
#   'rememb',
#   'with',
#   'golden',
#   'word',
#   'in',
#   'the',
#   'annal',
#   'of',
#   'indian',
#   'cinema',
#   's',
#   'histori',
#   'for',
#   'endeavor',
#   'to',
#   'complet',
#   'this',
#   'movi',
#   'in',
#   'a',
#   'record',
#   'set',
#   'year'],
#  ['he',
#   'had',
#   'to',
#   'manag',
#   'film',
#   'of',
#   'some',
#   'of',
#   'the',
#   'vital',
#   'song',
#   'without',
#   'meena',
#   's',
#   'close',
#   'up',
#   'becaus',
#   'meena',
#   'kumari',
#   'the',
#   'ladi',
#   'in',
#   'the',
#   'lead',
#   'role',
#   'was',
#   'termin',
#   'ill',
#   'and',
#   'fight',
#   'for',
#   'her',
#   'life',
#   'in',
#   'earli'],
#  ['most',
#   'peopl',
#   'especi',
#   'young',
#   'peopl',
#   'may',
#   'not',
#   'understand',
#   'this',
#   'film'],
#  ['it',
#   'look',
#   'like',
#   'a',
#   'stori',
#   'of',
#   'loss',
#   'when',
#   'it',
#   'is',
#   'actual',
#   'a',
#   'stori',
#   'about',
#   'be',
#   'alon'],
#  ['some',
#   'peopl',
#   'may',
#   'never',
#   'feel',
#   'loneli',
#   'at',
#   'this',
#   'level',
#   'cheadl',
#   'charact',
#   'johnson',
#   'reflect',
#   'the',
#   'total',
#   'opposit',
#   'of',
#   'sandler',
#   'charact',
#   'fineman'],
#  ['where',
#   'johnson',
#   'felt',
#   'trap',
#   'by',
#   'his',
#   'bless',
#   'fineman',
#   'was',
#   'tri',
#   'to',
#   'forget',
#   'his',
#   'life',
#   'in',
#   'the',
#   'same',
#   'perspect'],
#  ['jada',
#   'is',
#   'a',
#   'wonder',
#   'addit',
#   'to',
#   'the',
#   'cast',
#   'and',
#   'sandler',
#   'pull',
#   'tear'],
#  ['cheadl',
#   'had',
#   'the',
#   'comic',
#   'role',
#   'and',
#   'was',
#   'a',
#   'great',
#   'support',
#   'for',
#   'sandler',
#   'i',
#   'see',
#   'oscar',
#   'somewher',
#   'here'],
#  ['a', 'veri', 'fine', 'film'],
#  ['if',
#   'you',
#   'have',
#   'ever',
#   'lost',
#   'and',
#   'felt',
#   'alon',
#   'this',
#   'film',
#   'will',
#   'assur',
#   'you',
#   'that',
#   'you',
#   're',
#   'not',
#   'alon',
#   'jerri'],
#  ['soylent',
#   'green',
#   'is',
#   'one',
#   'of',
#   'the',
#   'best',
#   'and',
#   'most',
#   'disturb',
#   'scienc',
#   'fiction',
#   'movi',
#   'of',
#   'the',
#   's',
#   'and',
#   'still',
#   'veri',
#   'persuas',
#   'even',
#   'by',
#   'today',
#   's',
#   'standard'],
#  ['although',
#   'flaw',
#   'and',
#   'a',
#   'littl',
#   'date',
#   'the',
#   'apocalypt',
#   'touch',
#   'and',
#   'the',
#   'environment',
#   'premis',
#   'typic',
#   'for',
#   'that',
#   'time',
#   'still',
#   'feel',
#   'veri',
#   'unsettl',
#   'and',
#   'thought',
#   'provok'],
#  ['this',
#   'film',
#   's',
#   'qualiti',
#   'level',
#   'surpass',
#   'the',
#   'major',
#   'of',
#   'contemporari',
#   'sf',
#   'flick',
#   'becaus',
#   'of',
#   'it',
#   'strong',
#   'cast',
#   'and',
#   'some',
#   'intens',
#   'sequenc',
#   'that',
#   'i',
#   'person',
#   'consid',
#   'classic'],
#  ['the',
#   'new',
#   'york',
#   'of',
#   'is',
#   'a',
#   'depress',
#   'place',
#   'to',
#   'be',
#   'aliv',
#   'with',
#   'over',
#   'popul',
#   'unemploy',
#   'an',
#   'unhealthi',
#   'climat',
#   'and',
#   'the',
#   'total',
#   'scarciti',
#   'of',
#   'everi',
#   'vital',
#   'food',
#   'product'],
#  ['the',
#   'onli',
#   'form',
#   'of',
#   'food',
#   'avail',
#   'is',
#   'synthet',
#   'and',
#   'distribut',
#   'by',
#   'the',
#   'soylent',
#   'compani'],
#  ['charlton',
#   'heston',
#   'in',
#   'a',
#   'great',
#   'shape',
#   'play',
#   'a',
#   'cop',
#   'investig',
#   'the',
#   'murder',
#   'of',
#   'one',
#   'of',
#   'soylent',
#   's',
#   'most',
#   'emin',
#   'execut',
#   'and',
#   'he',
#   'stumbl',
#   'upon',
#   'scandal',
#   'and',
#   'dark',
#   'secret'],
#  ['the',
#   'script',
#   'is',
#   'a',
#   'littl',
#   'over',
#   'sentiment',
#   'at',
#   'time',
#   'and',
#   'the',
#   'climax',
#   'doesn',
#   't',
#   'realli',
#   'come',
#   'as',
#   'a',
#   'big',
#   'surpris',
#   'still',
#   'the',
#   'atmospher',
#   'is',
#   'veri',
#   'tens',
#   'and',
#   'uncanni'],
#  ['the',
#   'riot',
#   'sequenc',
#   'is',
#   'truli',
#   'gruel',
#   'and',
#   'easili',
#   'one',
#   'of',
#   'the',
#   'most',
#   'macabr',
#   'moment',
#   'in',
#   's',
#   'cinema'],
#  ['edward',
#   'g',
#   'robinson',
#   'is',
#   'ultim',
#   'impress',
#   'in',
#   'his',
#   'last',
#   'role',
#   'and',
#   'there',
#   's',
#   'a',
#   'great',
#   'but',
#   'too',
#   'modest',
#   'support',
#   'role',
#   'for',
#   'joseph',
#   'cotton',
#   'baron',
#   'blood',
#   'the',
#   'abomin',
#   'dr',
#   'phibe'],
#  ['this',
#   'is',
#   'scienc',
#   'fiction',
#   'in',
#   'my',
#   'book',
#   'a',
#   'nightmarish',
#   'and',
#   'inevit',
#   'fade',
#   'for',
#   'human'],
#  ['no',
#   'fanci',
#   'space',
#   'ship',
#   'with',
#   'hairi',
#   'monster',
#   'attack',
#   'our',
#   'planet'],
#  ['michael',
#   'stearn',
#   'play',
#   'mike',
#   'a',
#   'sexual',
#   'frustrat',
#   'individu',
#   'with',
#   'an',
#   'interest',
#   'moral',
#   'attitud',
#   'toward',
#   'sexual'],
#  ['he',
#   'has',
#   'no',
#   'problem',
#   'ogl',
#   'nake',
#   'dancer',
#   'but',
#   'when',
#   'women',
#   'start',
#   'have',
#   'sex',
#   'with',
#   'men',
#   'that',
#   's',
# ...
#   'well'],
#  ['i', 'gave', 'to', 'this', 'film'],
#  ['i',
#   'can',
#   't',
#   'understand',
#   'how',
#   'ettor',
#   'scola',
#   'one',
#   'of',
#   'the',
#   'greater',
#   'director',
#   'of',
#   'italian',
#   'cinema',
#   'made',
#   'a',
#   'film',
#   'like',
#   'this',
#   'so',
#   'stupid',
#   'and',
#   'ridicul'],
#  ['all',
#   'the',
#   'stori',
#   'of',
#   'the',
#   'peopl',
#   'involv',
#   'in',
#   'the',
#   'movi',
#   'are',
#   'unsubstanti',
#   'bore',
#   'and',
#   'not',
#   'interest'],
#  ['too', 'long', 'too', 'bore'],
#  ['the',
#   'onli',
#   'thing',
#   'i',
#   'save',
#   'in',
#   'this',
#   'movi',
#   'are',
#   'giancarlo',
#   'giannini',
#   'and',
#   'vittorio',
#   'gasmann'],
#  ['hope',
#   'that',
#   'scola',
#   'will',
#   'chang',
#   'radic',
#   'theme',
#   'and',
#   'style',
#   'in',
#   'his',
#   'next',
#   'film'],
#  ['as',
#   'a',
#   'big',
#   'fan',
#   'of',
#   'david',
#   'mamet',
#   's',
#   'film',
#   'and',
#   'play',
#   'especi',
#   'his',
#   'first',
#   'film',
#   'hous',
#   'of',
#   'game',
#   'that',
#   'also',
#   'star',
#   'joe',
#   'mantegna',
#   'i',
#   'was',
#   'expect',
#   'great',
#   'thing',
#   'from',
#   'this',
#   'film'],
#  ['instead',
#   'i',
#   'found',
#   'myself',
#   'annoy',
#   'by',
#   'the',
#   'film',
#   's',
#   'superfici',
#   'and',
#   'lack',
#   'of',
#   'credibl'],
#  ['racial',
#   'slur',
#   'are',
#   'thrown',
#   'about',
#   'without',
#   'ani',
#   'feel',
#   'or',
#   'mean',
#   'behind',
#   'them',
#   'in',
#   'the',
#   'hope',
#   'of',
#   'set',
#   'up',
#   'a',
#   'racial',
#   'tension',
#   'that',
#   'for',
#   'me',
#   'never',
#   'materi'],
#  ['ident',
#   'is',
#   'total',
#   'reevalu',
#   'and',
#   'men',
#   'becom',
#   'hero',
#   'for',
#   'no',
#   'appar',
#   'reason'],
#  ['becaus',
#   'of',
#   'his',
#   'oath',
#   'taken',
#   'as',
#   'a',
#   'cop',
#   'the',
#   'lead',
#   'charact',
#   'adam',
#   'refus',
#   'to',
#   'perform',
#   'one',
#   'relat',
#   'small',
#   'action',
#   'that',
#   'would',
#   'harm',
#   'no',
#   'one',
#   'and',
#   'could',
#   'possibl',
#   'save',
#   'live',
#   'and',
#   'yet',
#   'perform',
#   'anoth',
#   'action',
#   'which',
#   'is',
#   'veri',
#   'violent',
#   'and',
#   'veri',
#   'illeg',
#   'but',
#   'then',
#   'still',
#   'refus',
#   'the',
#   'minor',
#   'action'],
#  ['in',
#   'addit',
#   'a',
#   'high',
#   'unbeliev',
#   'subplot',
#   'involv',
#   'a',
#   'man',
#   'who',
#   'has',
#   'kill',
#   'his',
#   'famili',
#   'is',
#   'introduc',
#   'just',
#   'for',
#   'the',
#   'sake',
#   'of',
#   'a',
#   'plot',
#   'point',
#   'that',
#   'was',
#   'all',
#   'but',
#   'advertis',
#   'with',
#   'skywrit',
#   'and',
#   'the',
#   'cop',
#   's',
#   'reaction',
#   'to',
#   'that',
#   'occurr',
#   'stretch',
#   'credul',
#   'way',
#   'beyond',
#   'all',
#   'reason',
#   'limit'],
#  ['needless',
#   'to',
#   'say',
#   'after',
#   'expect',
#   'anoth',
#   'excit',
#   'thriller',
#   'from',
#   'david',
#   'mamet',
#   'i',
#   'was',
#   'extrem',
#   'disappoint',
#   'to',
#   'say',
#   'the',
#   'least'],
#  ['out', 'of'],
#  ['i',
#   'may',
#   'not',
#   'be',
#   'a',
#   'critic',
#   'but',
#   'here',
#   'is',
#   'what',
#   'i',
#   'think',
#   'of',
#   'this',
#   'movi'],
#  ['well',
#   'just',
#   'watch',
#   'the',
#   'movi',
#   'on',
#   'cinemax',
#   'and',
#   'first',
#   'of',
#   'all',
#   'i',
#   'just',
#   'have',
#   'to',
#   'say',
#   'how',
#   'much',
#   'i',
#   'hate',
#   'the',
#   'storylin',
#   'i',
#   'mean',
#   'come',
#   'on',
#   'what',
#   'doe',
#   'a',
#   'snowman',
#   'scare',
#   'besid',
#   'littl',
#   'kid',
#   'second',
#   'it',
#   'is',
#   'pretti',
#   'gori',
#   'but',
#   'i',
#   'bet',
#   'sinc',
#   'the',
#   'movi',
#   'is',
#   'so',
#   'low',
#   'budget',
#   'they',
#   'probabl',
#   'use',
#   'ketchup',
#   'so',
#   'my',
#   'critic',
#   'vote',
#   'is',
#   'bomb'],
#  ['nice',
#   'tri',
#   'and',
#   'the',
#   'sequel',
#   'will',
#   'suck',
#   'twice',
#   'as',
#   'much'],
#  ['there',
#   'is',
#   'a',
#   'uk',
#   'edit',
#   'to',
#   'this',
#   'show',
#   'which',
#   'is',
#   'rather',
#   'less',
#   'extravag',
#   'than',
#   'the',
#   'us',
#   'version'],
#  ['the',
#   'person',
#   'concern',
#   'will',
#   'get',
#   'a',
#   'new',
#   'kitchen',
#   'or',
#   'perhap',
#   'bedroom',
#   'and',
#   'bathroom',
#   'and',
#   'is',
#   'wonder',
#   'grate',
#   'for',
#   'what',
#   'they',
#   'have',
#   'got'],
#  ['the',
#   'us',
#   'version',
#   'of',
#   'this',
#   'show',
#   'is',
#   'everyth',
#   'that',
#   'realiti',
#   'tv',
#   'shouldn',
#   't',
#   'be'],
#  ['instead',
#   'of',
#   'make',
#   'a',
#   'few',
#   'improv',
#   'to',
#   'a',
#   'hous',
#   'which',
#   'the',
#   'occup',
#   'could',
#   'not',
#   'afford',
#   'or',
#   'do',
#   'themselv',
#   'the',
#   'entir',
#   'hous',
#   'get',
#   'rebuilt'],
#  ['i',
#   'do',
#   'not',
#   'know',
#   'if',
#   'this',
#   'show',
#   'is',
#   'tri',
#   'to',
#   'show',
#   'what',
#   'a',
#   'lousi',
#   'welfar',
#   'system',
#   'exist',
#   'in',
#   'the',
#   'us',
#   'or',
#   'if',
#   'you',
#   'beg',
#   'hard',
#   'enough',
#   'you',
#   'will',
#   'receiv'],
#  ['the',
#   'rather',
#   'vulgar',
#   'product',
#   'placement',
#   'that',
#   'take',
#   'place',
#   'particular',
#   'by',
#   'sear',
#   'is',
#   'also',
#   'uncal',
#   'for'],
#  ['rsther',
#   'than',
#   'turn',
#   'one',
#   'famili',
#   'in',
#   'a',
#   'depriv',
#   'area',
#   'into',
#   'potenti',
#   'millionair',
#   'it',
#   'would',
#   'be',
#   'far',
#   'better',
#   'to',
#   'help',
#   'the',
#   'communiti',
#   'as',
#   'a',
#   'whole',
#   'where',
#   'instead',
#   'of',
#   'spend',
#   'the',
#   'hundr',
#   'of',
#   'thousand',
#   'of',
#   'dollar',
#   'on',
#   'one',
#   'home',
#   'build',
#   'someth',
#   'for',
#   'the',
#   'whole',
#   'communiti',
#   'perhap',
#   'a',
#   'place',
#   'where',
#   'diy',
#   'and',
#   'power',
#   'tool',
#   'can',
#   'be',
#   'borrow',
#   'and',
#   'return',
#   'along',
#   'with',
#   'build',
#   'materi',
#   'so',
#   'that',
#   'everyon',
#   'can',
#   'benefit',
#   'should',
#   'they',
#   'want',
#   'to'],
#  ['give',
#   'it',
#   'all',
#   'to',
#   'one',
#   'person',
#   'can',
#   'caus',
#   'enorm',
#   'resent',
#   'among',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'local',
#   'communiti',
#   'who',
#   'still',
#   'live',
#   'in',
#   'the',
#   'same',
#   'run',
#   'down',
#   'hous'],
#  ['hello',
#   'mari',
#   'lou',
#   'prom',
#   'night',
#   'ii',
#   'start',
#   'at',
#   'the',
#   'hamilton',
#   'high',
#   'school',
#   'prom',
#   'of',
#   'where',
#   'mari',
#   'lou',
#   'maloney',
#   'lisa',
#   'schrage',
#   'is',
#   'cheat',
#   'on',
#   'her',
#   'date',
#   'bill',
#   'nordham',
#   'steve',
#   'atkinson',
#   'with',
#   'bud',
#   'cooper',
#   'robert',
#   'lewi'],
#  ['bill',
#   'find',
#   'out',
#   'is',
#   'devast',
#   'meanwhil',
#   'mari',
#   'lou',
#   'is',
#   'announc',
#   'prom',
#   'queen',
#   'take',
#   'to',
#   'the',
#   'stage',
#   'to',
#   'accept',
#   'her',
#   'award'],
#  ['bill',
#   'still',
#   'hurt',
#   'decid',
#   'to',
#   'play',
#   'a',
#   'practic',
#   'joke',
#   'on',
#   'mari',
#   'lou',
#   'so',
#   'he',
#   'throw',
#   'a',
#   'firecrack',
#   'on',
#   'stage',
#   'but',
#   'the',
#   'still',
#   'lit',
#   'fuse',
#   'catch',
#   'mari',
#   'lou',
#   's',
#   'dress',
#   'set',
#   'it',
#   'her',
#   'on',
#   'fire',
#   'within',
#   'second',
#   'mari',
#   'lou',
#   'is',
#   'toast'],
#  ['year',
#   'later',
#   'hamilton',
#   'high',
#   'is',
#   'soon',
#   'to',
#   'hold',
#   'it',
#   's',
#   'annual',
#   'prom',
#   'night'],
#  ['bill',
#   'micheal',
#   'ironsid',
#   'is',
#   'now',
#   'the',
#   'princip',
#   'has',
#   'a',
#   'teenag',
#   'son',
#   'name',
#   'craig',
#   'justin',
#   'loui',
#   'who',
#   'is',
#   'date',
#   'vicki',
#   'carpent',
#   'wendi',
#   'lyon',
#   'are',
#   'both',
#   'plan',
#   'on',
#   'go',
#   'to',
#   'the',
#   'prom',
#   'togeth'],
#  ['bud',
#   'richard',
#   'monett',
#   'is',
#   'now',
#   'a',
#   'priest',
#   'that',
#   'terribl',
#   'night',
#   'year',
#   'ago',
#   'still',
#   'haunt',
#   'both',
#   'bill',
#   'bud'],
#  ['one',
#   'day',
#   'vicki',
#   'is',
#   'look',
#   'around',
#   'the',
#   'school',
#   'basement',
#   'when',
#   'she',
#   'discov',
#   'a',
#   'larg',
#   'trunk',
#   'which',
#   'she',
#   'open',
#   'this',
#   'turn',
#   'out',
#   'to',
#   'be',
#   'a',
#   'bad',
#   'move',
#   'as',
#   'the',
#   'veng',
#   'spirit',
#   'of',
#   'mari',
#   'lou',
#   'is',
#   'set',
#   'free',
#   'is',
#   'intent',
#   'on',
#   'claim',
#   'her',
#   'crown',
#   'as',
#   'prom',
#   'queen',
#   'in',
#   'her',
#   'spare',
#   'time',
#   'set',
#   'out',
#   'to',
#   'aveng',
#   'her',
#   'untim',
#   'death'],
#  ['first',
#   'up',
#   'is',
#   'jess',
#   'brown',
#   'beth',
#   'gondek',
#   'whose',
#   'death',
#   'is',
#   'put',
#   'down',
#   'to',
#   'a',
#   'suicid',
#   'mari',
#   'lou',
#   'begin',
#   'to',
#   'poss',
#   'vicki',
#   's',
#   'bodi',
#   'as',
#   'the',
#   'night',
#   'of',
#   'the',
#   'prom',
#   'draw',
#   'nearer'],
#  ['after',
#   'dispos',
#   'of',
#   'some',
#   'competit',
#   'in',
#   'the',
#   'shape',
#   'of',
#   'kelli',
#   'hennenlott',
#   'terri',
#   'hawk',
#   'who',
#   'tri',
#   'to',
#   'fix',
#   'the',
#   'prom',
#   'so',
#   'she',
#   'win'],
#  ['mari',
#   'lou',
#   'in',
#   'vicki',
#   's',
#   'bodi',
#   'is',
#   'crown',
#   'hamilton',
#   'high',
#   'prom',
#   'queen',
#   'which',
#   'allow',
#   'mari',
#   'lou',
#   'herself',
#   'to',
#   'come',
#   'back',
#   'from',
#   'the',
#   'dead',
#   'to',
#   'make',
#   'an',
#   'unexpect',
#   'appear',
#   'realli',
#   'liven',
#   'the',
#   'parti',
#   'up',
#   'with',
#   'absolut',
#   'no',
#   'connect',
#   'to',
#   'the',
#   'origin',
#   'prom',
#   'night',
#   'direct',
#   'by',
#   'bruce',
#   'pittman',
#   'i',
#   'thought',
#   'hello',
#   'mari',
#   'lou',
#   'prom',
#   'night',
#   'ii',
#   'wasn',
#   't',
#   'a',
#   'particular',
#   'good',
#   'film'],
#  ['the',
#   'script',
#   'by',
#   'ron',
#   'oliv',
#   'concentr',
#   'more',
#   'on',
#   'supernatur',
#   'element',
#   'rather',
#   'than',
#   'cheap',
#   'teen',
#   'slasher',
#   'theme',
#   'whether',
#   'this',
#   'was',
#   'a',
#   'good',
#   'or',
#   'bad',
#   'decis',
#   'will',
#   'depend',
#   'on',
#   'your',
#   'expect',
#   'i',
#   'suppos'],
#  ['person',
#   'i',
#   'found',
#   'these',
#   'differ',
#   'element',
#   'didn',
#   't',
#   'realli',
#   'gel',
#   'or',
#   'work',
#   'that',
#   'well',
#   'togeth',
#   'at',
#   'all'],
#  ['the',
#   'whole',
#   'film',
#   'was',
#   'far',
#   'to',
#   'slow',
#   'to',
#   'be',
#   'realli',
#   'enjoy',
#   'after',
#   'the',
#   'open',
#   'sequenc',
#   'where',
#   'mari',
#   'lou',
#   'die',
#   'no',
#   'one',
#   'els',
#   'is',
#   'kill',
#   'until',
#   'the',
#   'half',
#   'hour',
#   'mark',
#   'then',
#   'the',
#   'film',
#   'plod',
#   'along',
#   'for',
#   'anoth',
#   'half',
#   'an',
#   'hour',
#   'until',
#   'vicki',
#   'is',
#   'final',
#   'possess',
#   'the',
#   'film',
#   'final',
#   'pick',
#   'up',
#   'momentum',
#   'for',
#   'the',
#   'climax',
#   'where',
#   'an',
#   'evil',
#   'mari',
#   'lou',
#   'kill',
#   'a',
#   'whole',
#   'one',
#   'person',
#   'at',
#   'the',
#   'prom',
#   'befor',
#   'she',
#   'is',
#   'suppos',
#   'defeat',
#   'come',
#   'on',
#   'horror',
#   'film',
#   'fan',
#   'you',
#   'did',
#   'expect',
#   'that',
#   'clich',
#   'd',
#   'killer',
#   'not',
#   'dead',
#   'readi',
#   'for',
#   'a',
#   'sequel',
#   'end',
#   'didn',
#   't',
#   'you'],
#  ['don',
#   't',
#   'expect',
#   'a',
#   'hight',
#   'bodi',
#   'count',
#   'just',
#   'five',
#   'throughout',
#   'the',
#   'entir',
#   'film',
#   'none',
#   'particular',
#   'graphic',
#   'although',
#   'i',
#   'did',
#   'like',
#   'the',
#   'way',
#   'monica',
#   'beverley',
#   'hendri',
#   'as',
#   'bever',
#   'hendri',
#   'tri',
#   'to',
#   'hide',
#   'in',
#   'a',
#   'shower',
#   'room',
#   'locker',
#   'which',
#   'mari',
#   'lou',
#   'crush',
#   'result',
#   'in',
#   'poor',
#   'monica',
#   's',
#   'blood',
#   'ooz',
#   'out'],
#  ['the',
#   'supernatur',
#   'side',
#   'of',
#   'hello',
#   'mari',
#   'lou',
#   'prom',
#   'night',
#   'ii',
#   'is',
#   'depict',
#   'by',
#   'vicki',
#   'have',
#   'lot',
#   'of',
#   'hallucin',
#   'for',
#   'the',
#   'first',
#   'hour',
#   'mari',
#   'lou',
#   'control',
#   'object',
#   'dure',
#   'the',
#   'latter',
#   'stage',
#   'includ',
#   'a',
#   'coupl',
#   'of',
#   'creepi',
#   'shot',
#   'of',
#   'a',
#   'rock',
#   'hors',
#   'which',
#   'come',
#   'to',
#   'life',
#   'the',
#   'blackboard',
#   'scene',
#   'is',
#   'quit',
#   'good',
#   'as',
#   'well',
#   'as',
#   'it',
#   'turn',
#   'into',
#   'water',
#   'zombi',
#   'hand',
#   'drag',
#   'vicki',
#   'into',
#   'it'],
#  ['the',
#   'slasher',
#   'side',
#   'of',
#   'hello',
#   'mari',
#   'lou',
#   'prom',
#   'night',
#   'ii',
#   'isn',
#   't',
#   'outstand',
#   'i',
#   'did',
#   'like',
#   'mari',
#   'lou',
#   'herself',
#   'as',
#   'she',
#   'churn',
#   'out',
#   'the',
#   'obligatori',
#   'one',
#   'liner',
#   'she',
#   'made',
#   'for',
#   'a',
#   'good',
#   'villain',
#   'even',
#   'if',
#   'she',
#   'didn',
#   't',
#   'get',
#   'to',
#   'kill',
#   'enough',
#   'peopl'],
#  ['oh',
#   'yes',
#   'i',
#   'did',
#   'get',
#   'the',
#   'run',
#   'homag',
#   'to',
#   'various',
#   'other',
#   'horror',
#   'film',
#   'director',
#   's',
#   'with',
#   'almost',
#   'all',
#   'of',
#   'the',
#   'charact',
#   's',
#   'share',
#   'last',
#   'name',
#   'with',
#   'one',
#   'this',
#   'obvious',
#   'add',
#   'noth',
#   'to',
#   'the',
#   'film',
#   'but',
#   'is',
#   'a',
#   'nice',
#   'littl',
#   'touch',
#   'i',
#   'suppos'],
#  ['the',
#   'act',
#   'is',
#   'ok',
#   'but',
#   'the',
#   'normal',
#   'depend',
#   'micheal',
#   'ironsid',
#   'look',
#   'lost',
#   'uninterest',
#   'almost',
#   'as',
#   'if',
#   'he',
#   's',
#   'ask',
#   'himself',
#   'what',
#   'he',
#   's',
#   'do',
#   'in',
#   'this',
#   'if',
#   'he',
#   'll',
#   'ever',
#   'work',
#   'again'],
#  ['forget',
#   'about',
#   'ani',
#   'gore',
#   'someon',
#   'is',
#   'hang',
#   'there',
#   'is',
#   'a',
#   'stab',
#   'with',
#   'a',
#   'crucifix',
#   'that',
#   'happen',
#   'off',
#   'screen',
#   'someon',
#   'is',
#   'impal',
#   'with',
#   'a',
#   'neon',
#   'light',
#   'a',
#   'comput',
#   'goe',
#   'crazi',
#   'electrocut',
#   'someon',
#   'face'],
#  ['mari',
#   'lou',
#   'burst',
#   'out',
#   'of',
#   'vicki',
#   's',
#   'bodi',
#   'at',
#   'first',
#   'as',
#   'a',
#   'rot',
#   'zombi',
#   'which',
#   'was',
#   'quit',
#   'a',
#   'cool',
#   'scene'],
#  ['there',
#   'are',
#   'some',
#   'full',
#   'frontal',
#   'nuditi',
#   'shot',
#   'in',
#   'the',
#   'girl',
#   'shower',
#   'as',
#   'well',
#   'if',
#   'that',
#   's',
#   'your',
#   'thing'],
#  ['to',
#   'give',
#   'it',
#   'some',
#   'credit',
#   'hello',
#   'mari',
#   'lou',
#   'prom',
#   'night',
#   'ii',
#   'is',
#   'ok',
#   'to',
#   'watch',
#   'has',
#   'reason',
#   'product',
#   'valu',
#   'throughout',
#   'is',
#   'general',
#   'well',
#   'made'],
#  ['overal',
#   'i',
#   'was',
#   'disappoint',
#   'by',
#   'hello',
#   'mari',
#   'lou',
#   'prom',
#   'night',
#   'ii',
#   'it',
#   'was',
#   'just',
#   'too',
#   'slow',
#   'ultim',
#   'unev',
#   'to',
#   'maintain',
#   'my',
#   'interest',
#   'for',
#   'near',
#   'minut'],
#  ['i',
#   'm',
#   'not',
#   'sure',
#   'whether',
#   'it',
#   'deserv',
#   'a',
#   'or',
#   'star',
#   'rate',
#   'i',
#   'll',
#   'give',
#   'it',
#   'a',
#   'as',
#   'there',
#   's',
#   'noth',
#   'specif',
#   'wrong',
#   'with',
#   'it',
#   'i',
#   'suppos',
#   'i',
#   've',
#   'sat',
#   'through',
#   'much',
#   'wors',
#   'film',
#   'but',
#   'it',
#   'just',
#   'didn',
#   't',
#   'realli',
#   'do',
#   'anyth',
#   'for',
#   'me',
#   'i',
#   'm',
#   'afraid'],
#  ['a',
#   'veri',
#   'good',
#   'stori',
#   'for',
#   'a',
#   'film',
#   'which',
#   'if',
#   'done',
#   'proper',
#   'would',
#   'be',
#   'quit',
#   'interest',
#   'but',
#   'where',
#   'the',
#   'hell',
#   'is',
#   'the',
#   'end',
#   'to',
#   'this',
#   'film',
#   'in',
#   'fact',
#   'what',
#   'is',
#   'the',
#   'point',
#   'of',
#   'it',
#   'the',
#   'scene',
#   'zip',
#   'through',
#   'so',
#   'quick',
#   'that',
#   'you',
#   'felt',
#   'you',
#   'were',
#   'not',
#   'part',
#   'of',
#   'the',
#   'film',
#   'emot',
#   'and',
#   'the',
#   'feel',
#   'of',
#   'be',
#   'detach',
#   'from',
#   'understand',
#   'the',
#   'storylin',
#   'the',
#   'perform',
#   'of',
#   'the',
#   'cast',
#   'are',
#   'question',
#   'if',
#   'not',
#   'believ',
#   'did',
#   'i',
#   'miss',
#   'the',
#   'conclus',
#   'somewher',
#   'in',
#   'the',
#   'film'],
#  ['i', 'guess', 'we', 'have', 'to', 'wait', 'for', 'the', 'sequel'],
#  ['elvira',
#   'cassandra',
#   'peterson',
#   'is',
#   'the',
#   'host',
#   'of',
#   'a',
#   'cheap',
#   'horror',
#   'show'],
#  ['after',
#   'she',
#   'find',
#   'out',
#   'that',
#   'her',
#   'dead',
#   'aunt',
#   'has',
#   'left',
#   'her',
#   'some',
#   'stuff',
#   'elvira',
#   'goe',
#   'to',
#   'england',
#   'to',
#   'pick',
#   'it',
#   'up',
#   'hope',
#   'it',
#   'will',
#   'be',
#   'some',
#   'money'],
#  ['but',
#   'to',
#   'her',
#   'horror',
#   'elvira',
#   'find',
#   'out',
#   'that',
#   'all',
#   'her',
#   'aunt',
#   'has',
#   'left',
#   'her',
#   'is',
#   'her',
#   'hous',
#   'her',
#   'dog',
#   'and',
#   'a',
#   'cookbook'],
#  ['elvira',
#   'decid',
#   'to',
#   'settl',
#   'in',
#   'the',
#   'hous',
#   'anyway',
#   'but',
#   'with',
#   'her',
#   'strike',
#   'dark',
#   'look',
#   'and',
#   'her',
#   'stun',
#   'featur',
#   'she',
#   'will',
#   'not',
#   'be',
#   'abl',
#   'to',
#   'live',
#   'in',
#   'peac'],
#  ...]

# %%
for review in unlabeled_train["review"]:
    sentences += kaggleBagofWord.review_to_sentences(
        review, remove_stopwords=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.archive.org/details/LovefromaStranger"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.loosechangeguide.com/LooseChangeGuide.html"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'... ...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'....'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.msnbc.msn.com/id/4972055/site/newsweek/"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'12.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://www.youtube.com/watch?v=a0KSqelmgN8"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:219: UserWarning: "b'.. .'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:282: UserWarning: "http://jake-weird.blogspot.com/2007/08/beneath.html"" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
len(sentences)
# Out:
# 795538

# %%
sentences[0][:10]
# Out:
# ['with', 'all', 'this', 'stuff', 'go', 'down', 'at', 'the', 'moment', 'with']

# %%
sentences[1][:10]
# Out:
# ['mayb', 'i', 'just', 'want', 'to', 'get', 'a', 'certain', 'insight', 'into']

# %% [markdown]
# Word2Vec 모델의 파라메터
#
# * 아키텍처 : 아키텍처 옵션은 skip-gram (default) 또는 CBOW 모델이다. skip-gram (default)은 느리지 만 더 나은 결과를 낸다.
#
# * 학습 알고리즘 : Hierarchical softmax (default) 또는 negative 샘플링. 여기에서는 기본값이 잘 동작한다.
#
# * 빈번하게 등장하는 단어에 대한 다운 샘플링 : Google 문서는 .00001에서 .001 사이의 값을 권장한다. 여기에서는 0.001에 가까운 값이 최종 모델의 정확도를 높이는 것으로 보여진다.
#
# * 단어 벡터 차원 : 많은 feature를 사용한다고 항상 좋은 것은 아니지만 대체적으로 좀 더 나은 모델이 된다. 합리적인 값은 수십에서 수백 개가 될 수 있고 여기에서는 300으로 지정했다.
#
# * 컨텍스트 / 창 크기 : 학습 알고리즘이 고려해야하는 컨텍스트의 단어 수는 얼마나 될까? hierarchical softmax 를 위해 좀 더 큰 수가 좋지만 10 정도가 적당하다.
#
# * Worker threads : 실행할 병렬 프로세스의 수로 컴퓨터마다 다르지만 대부분의 시스템에서 4에서 6 사이의 값을 사용하다.
#
# * 최소 단어 수 : 어휘의 크기를 의미있는 단어로 제한하는 데 도움이 된다. 모든 문서에서이 여러 번 발생하지 않는 단어는 무시된다. 10에서 100 사이가 적당하며, 이 경진대회의 데이터는 각 영화가 30개씩의 리뷰가 있기 때문에 개별 영화 제목에 너무 많은 중요성이 붙는 것을 피하기 위해 최소 단어 수를 40으로 설정한다. 그 결과 전체 어휘 크기는 약 15,000 단어가 된다. 높은 값은 제한 된 실행시간에 도움이 된다.

# %%
import logging
logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s', 
    level=logging.INFO)

# %%
# 파라메터값 지정
num_features = 300 # 문자 벡터 차원 수
min_word_count = 40 # 최소 단어 수
num_workers = 4 # 병렬 처리 스레드 수
context = 10 # 문자열 창 크기
downsampling = 1e-3 # 문자 빈도 수 Downsample

# 초기화 및 모델 학습
from gensim.models import word2vec

# 모델 학습
model = word2vec.Word2Vec(sentences, 
                          workers=num_workers, 
                          size=num_features, 
                          min_count=min_word_count,
                          window=context,
                          sample=downsampling)
model
# Out:
# 2018-04-18 17:11:05,747 : INFO : collecting all words and their counts
# 2018-04-18 17:11:05,749 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-04-18 17:11:05,868 : INFO : PROGRESS: at sentence #10000, processed 225803 words, keeping 12465 word types
# 2018-04-18 17:11:05,943 : INFO : PROGRESS: at sentence #20000, processed 451892 words, keeping 17070 word types
# 2018-04-18 17:11:06,021 : INFO : PROGRESS: at sentence #30000, processed 671315 words, keeping 20370 word types
# 2018-04-18 17:11:06,116 : INFO : PROGRESS: at sentence #40000, processed 897815 words, keeping 23125 word types
# 2018-04-18 17:11:06,194 : INFO : PROGRESS: at sentence #50000, processed 1116963 words, keeping 25365 word types
# 2018-04-18 17:11:06,281 : INFO : PROGRESS: at sentence #60000, processed 1338404 words, keeping 27283 word types
# 2018-04-18 17:11:06,374 : INFO : PROGRESS: at sentence #70000, processed 1561580 words, keeping 29024 word types
# 2018-04-18 17:11:06,474 : INFO : PROGRESS: at sentence #80000, processed 1780887 words, keeping 30603 word types
# 2018-04-18 17:11:06,583 : INFO : PROGRESS: at sentence #90000, processed 2004996 words, keeping 32223 word types
# 2018-04-18 17:11:06,701 : INFO : PROGRESS: at sentence #100000, processed 2226967 words, keeping 33579 word types
# 2018-04-18 17:11:06,805 : INFO : PROGRESS: at sentence #110000, processed 2446581 words, keeping 34827 word types
# 2018-04-18 17:11:06,927 : INFO : PROGRESS: at sentence #120000, processed 2668776 words, keeping 36183 word types
# 2018-04-18 17:11:07,059 : INFO : PROGRESS: at sentence #130000, processed 2894304 words, keeping 37353 word types
# 2018-04-18 17:11:07,390 : INFO : PROGRESS: at sentence #140000, processed 3107006 words, keeping 38376 word types
# 2018-04-18 17:11:07,684 : INFO : PROGRESS: at sentence #150000, processed 3332628 words, keeping 39556 word types
# 2018-04-18 17:11:07,856 : INFO : PROGRESS: at sentence #160000, processed 3555316 words, keeping 40629 word types
# 2018-04-18 17:11:07,969 : INFO : PROGRESS: at sentence #170000, processed 3778656 words, keeping 41628 word types
# 2018-04-18 17:11:08,113 : INFO : PROGRESS: at sentence #180000, processed 3999237 words, keeping 42599 word types
# 2018-04-18 17:11:08,286 : INFO : PROGRESS: at sentence #190000, processed 4224450 words, keeping 43461 word types
# 2018-04-18 17:11:08,388 : INFO : PROGRESS: at sentence #200000, processed 4448604 words, keeping 44301 word types
# 2018-04-18 17:11:08,496 : INFO : PROGRESS: at sentence #210000, processed 4669968 words, keeping 45212 word types
# 2018-04-18 17:11:08,606 : INFO : PROGRESS: at sentence #220000, processed 4894969 words, keeping 46134 word types
# 2018-04-18 17:11:08,713 : INFO : PROGRESS: at sentence #230000, processed 5117546 words, keeping 46986 word types
# 2018-04-18 17:11:08,835 : INFO : PROGRESS: at sentence #240000, processed 5345051 words, keeping 47854 word types
# 2018-04-18 17:11:08,947 : INFO : PROGRESS: at sentence #250000, processed 5559166 words, keeping 48699 word types
# 2018-04-18 17:11:09,031 : INFO : PROGRESS: at sentence #260000, processed 5779147 words, keeping 49469 word types
# 2018-04-18 17:11:09,206 : INFO : PROGRESS: at sentence #270000, processed 6000436 words, keeping 50416 word types
# 2018-04-18 17:11:09,291 : INFO : PROGRESS: at sentence #280000, processed 6226315 words, keeping 51640 word types
# 2018-04-18 17:11:09,431 : INFO : PROGRESS: at sentence #290000, processed 6449475 words, keeping 52754 word types
# 2018-04-18 17:11:09,507 : INFO : PROGRESS: at sentence #300000, processed 6674078 words, keeping 53755 word types
# 2018-04-18 17:11:09,597 : INFO : PROGRESS: at sentence #310000, processed 6899392 words, keeping 54734 word types
# 2018-04-18 17:11:09,677 : INFO : PROGRESS: at sentence #320000, processed 7124279 words, keeping 55770 word types
# 2018-04-18 17:11:10,112 : INFO : PROGRESS: at sentence #330000, processed 7346022 words, keeping 56687 word types
# 2018-04-18 17:11:11,599 : INFO : PROGRESS: at sentence #340000, processed 7575534 words, keeping 57629 word types
# 2018-04-18 17:11:11,900 : INFO : PROGRESS: at sentence #350000, processed 7798804 words, keeping 58485 word types
# 2018-04-18 17:11:12,082 : INFO : PROGRESS: at sentence #360000, processed 8019467 words, keeping 59345 word types
# 2018-04-18 17:11:12,251 : INFO : PROGRESS: at sentence #370000, processed 8246659 words, keeping 60161 word types
# 2018-04-18 17:11:12,459 : INFO : PROGRESS: at sentence #380000, processed 8471806 words, keeping 61069 word types
# 2018-04-18 17:11:12,624 : INFO : PROGRESS: at sentence #390000, processed 8701556 words, keeping 61810 word types
# 2018-04-18 17:11:12,898 : INFO : PROGRESS: at sentence #400000, processed 8924505 words, keeping 62546 word types
# 2018-04-18 17:11:13,221 : INFO : PROGRESS: at sentence #410000, processed 9145855 words, keeping 63263 word types
# 2018-04-18 17:11:13,525 : INFO : PROGRESS: at sentence #420000, processed 9366935 words, keeping 64024 word types
# 2018-04-18 17:11:13,829 : INFO : PROGRESS: at sentence #430000, processed 9594472 words, keeping 64795 word types
# 2018-04-18 17:11:14,011 : INFO : PROGRESS: at sentence #440000, processed 9821225 words, keeping 65539 word types
# 2018-04-18 17:11:14,307 : INFO : PROGRESS: at sentence #450000, processed 10044987 words, keeping 66378 word types
# 2018-04-18 17:11:14,554 : INFO : PROGRESS: at sentence #460000, processed 10277747 words, keeping 67158 word types
# 2018-04-18 17:11:14,784 : INFO : PROGRESS: at sentence #470000, processed 10505672 words, keeping 67775 word types
# 2018-04-18 17:11:15,048 : INFO : PROGRESS: at sentence #480000, processed 10726056 words, keeping 68500 word types
# 2018-04-18 17:11:15,642 : INFO : PROGRESS: at sentence #490000, processed 10952800 words, keeping 69256 word types
# 2018-04-18 17:11:15,955 : INFO : PROGRESS: at sentence #500000, processed 11174456 words, keeping 69892 word types
# 2018-04-18 17:11:16,332 : INFO : PROGRESS: at sentence #510000, processed 11399731 words, keeping 70593 word types
# 2018-04-18 17:11:16,548 : INFO : PROGRESS: at sentence #520000, processed 11623082 words, keeping 71267 word types
# 2018-04-18 17:11:16,783 : INFO : PROGRESS: at sentence #530000, processed 11847480 words, keeping 71877 word types
# 2018-04-18 17:11:17,016 : INFO : PROGRESS: at sentence #540000, processed 12072095 words, keeping 72537 word types
# 2018-04-18 17:11:17,359 : INFO : PROGRESS: at sentence #550000, processed 12297646 words, keeping 73212 word types
# 2018-04-18 17:11:17,579 : INFO : PROGRESS: at sentence #560000, processed 12518936 words, keeping 73861 word types
# 2018-04-18 17:11:17,790 : INFO : PROGRESS: at sentence #570000, processed 12748083 words, keeping 74431 word types
# 2018-04-18 17:11:17,891 : INFO : PROGRESS: at sentence #580000, processed 12969579 words, keeping 75087 word types
# 2018-04-18 17:11:18,008 : INFO : PROGRESS: at sentence #590000, processed 13195104 words, keeping 75733 word types
# 2018-04-18 17:11:18,101 : INFO : PROGRESS: at sentence #600000, processed 13417302 words, keeping 76294 word types
# 2018-04-18 17:11:18,379 : INFO : PROGRESS: at sentence #610000, processed 13638325 words, keeping 76952 word types
# 2018-04-18 17:11:18,491 : INFO : PROGRESS: at sentence #620000, processed 13864650 words, keeping 77503 word types
# 2018-04-18 17:11:18,585 : INFO : PROGRESS: at sentence #630000, processed 14088936 words, keeping 78066 word types
# 2018-04-18 17:11:18,831 : INFO : PROGRESS: at sentence #640000, processed 14309719 words, keeping 78692 word types
# 2018-04-18 17:11:18,900 : INFO : PROGRESS: at sentence #650000, processed 14535475 words, keeping 79295 word types
# 2018-04-18 17:11:18,963 : INFO : PROGRESS: at sentence #660000, processed 14758265 words, keeping 79864 word types
# 2018-04-18 17:11:19,725 : INFO : PROGRESS: at sentence #670000, processed 14981658 words, keeping 80381 word types
# 2018-04-18 17:11:20,085 : INFO : PROGRESS: at sentence #680000, processed 15206490 words, keeping 80912 word types
# 2018-04-18 17:11:20,176 : INFO : PROGRESS: at sentence #690000, processed 15428683 words, keeping 81482 word types
# 2018-04-18 17:11:20,247 : INFO : PROGRESS: at sentence #700000, processed 15657389 words, keeping 82074 word types
# 2018-04-18 17:11:20,322 : INFO : PROGRESS: at sentence #710000, processed 15880378 words, keeping 82560 word types
# 2018-04-18 17:11:20,419 : INFO : PROGRESS: at sentence #720000, processed 16105665 words, keeping 83036 word types
# 2018-04-18 17:11:20,500 : INFO : PROGRESS: at sentence #730000, processed 16332046 words, keeping 83571 word types
# 2018-04-18 17:11:20,575 : INFO : PROGRESS: at sentence #740000, processed 16553079 words, keeping 84127 word types
# 2018-04-18 17:11:20,694 : INFO : PROGRESS: at sentence #750000, processed 16771406 words, keeping 84599 word types
# 2018-04-18 17:11:20,795 : INFO : PROGRESS: at sentence #760000, processed 16990810 words, keeping 85068 word types
# 2018-04-18 17:11:20,882 : INFO : PROGRESS: at sentence #770000, processed 17217947 words, keeping 85644 word types
# 2018-04-18 17:11:21,081 : INFO : PROGRESS: at sentence #780000, processed 17448093 words, keeping 86160 word types
# 2018-04-18 17:11:21,337 : INFO : PROGRESS: at sentence #790000, processed 17675169 words, keeping 86665 word types
# 2018-04-18 17:11:21,440 : INFO : collected 86996 word types from a corpus of 17798270 raw words and 795538 sentences
# 2018-04-18 17:11:21,442 : INFO : Loading a fresh vocabulary
# 2018-04-18 17:11:21,630 : INFO : min_count=40 retains 11986 unique words (13% of original 86996, drops 75010)
# 2018-04-18 17:11:21,631 : INFO : min_count=40 leaves 17434033 word corpus (97% of original 17798270, drops 364237)
# 2018-04-18 17:11:21,760 : INFO : deleting the raw counts dictionary of 86996 items
# 2018-04-18 17:11:21,825 : INFO : sample=0.001 downsamples 50 most-common words
# 2018-04-18 17:11:21,827 : INFO : downsampling leaves estimated 12872363 word corpus (73.8% of prior 17434033)
# 2018-04-18 17:11:21,904 : INFO : estimated required memory for 11986 words and 300 dimensions: 34759400 bytes
# 2018-04-18 17:11:21,906 : INFO : resetting layer weights
# 2018-04-18 17:11:22,291 : INFO : training model with 4 workers on 11986 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2018-04-18 17:11:23,419 : INFO : EPOCH 1 - PROGRESS: at 2.34% examples, 296061 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:24,458 : INFO : EPOCH 1 - PROGRESS: at 4.81% examples, 300984 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:25,502 : INFO : EPOCH 1 - PROGRESS: at 6.90% examples, 285725 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:26,510 : INFO : EPOCH 1 - PROGRESS: at 10.09% examples, 313838 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:27,535 : INFO : EPOCH 1 - PROGRESS: at 13.19% examples, 328640 words/s, in_qsize 6, out_qsize 1
# 2018-04-18 17:11:28,557 : INFO : EPOCH 1 - PROGRESS: at 16.56% examples, 343361 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:29,558 : INFO : EPOCH 1 - PROGRESS: at 19.38% examples, 345726 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:30,558 : INFO : EPOCH 1 - PROGRESS: at 22.65% examples, 354670 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:31,565 : INFO : EPOCH 1 - PROGRESS: at 25.80% examples, 359859 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:32,580 : INFO : EPOCH 1 - PROGRESS: at 28.70% examples, 360875 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:33,607 : INFO : EPOCH 1 - PROGRESS: at 31.91% examples, 363829 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:34,607 : INFO : EPOCH 1 - PROGRESS: at 34.99% examples, 366480 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:35,627 : INFO : EPOCH 1 - PROGRESS: at 38.18% examples, 369369 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:36,629 : INFO : EPOCH 1 - PROGRESS: at 41.43% examples, 372820 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:37,645 : INFO : EPOCH 1 - PROGRESS: at 45.12% examples, 379281 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:38,670 : INFO : EPOCH 1 - PROGRESS: at 48.82% examples, 385101 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:39,670 : INFO : EPOCH 1 - PROGRESS: at 52.32% examples, 388705 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:40,680 : INFO : EPOCH 1 - PROGRESS: at 55.49% examples, 389719 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:41,731 : INFO : EPOCH 1 - PROGRESS: at 58.79% examples, 390931 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:42,733 : INFO : EPOCH 1 - PROGRESS: at 62.72% examples, 396543 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:43,755 : INFO : EPOCH 1 - PROGRESS: at 66.22% examples, 398871 words/s, in_qsize 5, out_qsize 2
# 2018-04-18 17:11:44,764 : INFO : EPOCH 1 - PROGRESS: at 69.94% examples, 402178 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:45,783 : INFO : EPOCH 1 - PROGRESS: at 73.85% examples, 406303 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:46,803 : INFO : EPOCH 1 - PROGRESS: at 77.60% examples, 409112 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:47,813 : INFO : EPOCH 1 - PROGRESS: at 81.59% examples, 413023 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:48,823 : INFO : EPOCH 1 - PROGRESS: at 85.58% examples, 416669 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:49,856 : INFO : EPOCH 1 - PROGRESS: at 89.42% examples, 419112 words/s, in_qsize 6, out_qsize 1
# 2018-04-18 17:11:50,860 : INFO : EPOCH 1 - PROGRESS: at 93.63% examples, 423349 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:51,869 : INFO : EPOCH 1 - PROGRESS: at 97.84% examples, 427227 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:52,333 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-04-18 17:11:52,360 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-18 17:11:52,368 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-18 17:11:52,373 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 17:11:52,374 : INFO : EPOCH - 1 : training on 17798270 raw words (12873611 effective words) took 30.0s, 429398 effective words/s
# 2018-04-18 17:11:53,403 : INFO : EPOCH 2 - PROGRESS: at 4.48% examples, 568984 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:54,405 : INFO : EPOCH 2 - PROGRESS: at 8.50% examples, 540350 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:55,410 : INFO : EPOCH 2 - PROGRESS: at 12.63% examples, 535075 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:11:56,421 : INFO : EPOCH 2 - PROGRESS: at 17.00% examples, 538998 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:57,426 : INFO : EPOCH 2 - PROGRESS: at 21.24% examples, 539007 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:11:58,437 : INFO : EPOCH 2 - PROGRESS: at 25.51% examples, 539605 words/s, in_qsize 8, out_qsize 1
# 2018-04-18 17:11:59,452 : INFO : EPOCH 2 - PROGRESS: at 29.70% examples, 538726 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:00,453 : INFO : EPOCH 2 - PROGRESS: at 33.55% examples, 531763 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:01,453 : INFO : EPOCH 2 - PROGRESS: at 36.62% examples, 516901 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:02,458 : INFO : EPOCH 2 - PROGRESS: at 40.30% examples, 512654 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:03,460 : INFO : EPOCH 2 - PROGRESS: at 43.87% examples, 508028 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:04,472 : INFO : EPOCH 2 - PROGRESS: at 47.39% examples, 503018 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:05,490 : INFO : EPOCH 2 - PROGRESS: at 51.36% examples, 503133 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:06,502 : INFO : EPOCH 2 - PROGRESS: at 55.72% examples, 506952 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:07,504 : INFO : EPOCH 2 - PROGRESS: at 59.89% examples, 509593 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:08,510 : INFO : EPOCH 2 - PROGRESS: at 63.33% examples, 505144 words/s, in_qsize 7, out_qsize 1
# 2018-04-18 17:12:09,511 : INFO : EPOCH 2 - PROGRESS: at 67.18% examples, 504745 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:10,511 : INFO : EPOCH 2 - PROGRESS: at 70.93% examples, 503590 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:11,521 : INFO : EPOCH 2 - PROGRESS: at 74.96% examples, 504192 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:12,536 : INFO : EPOCH 2 - PROGRESS: at 78.95% examples, 504258 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:13,562 : INFO : EPOCH 2 - PROGRESS: at 83.28% examples, 506088 words/s, in_qsize 8, out_qsize 1
# 2018-04-18 17:12:14,572 : INFO : EPOCH 2 - PROGRESS: at 86.19% examples, 499929 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:15,596 : INFO : EPOCH 2 - PROGRESS: at 89.68% examples, 497472 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:16,615 : INFO : EPOCH 2 - PROGRESS: at 93.23% examples, 495328 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:17,615 : INFO : EPOCH 2 - PROGRESS: at 96.86% examples, 494001 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:18,606 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-04-18 17:12:18,636 : INFO : EPOCH 2 - PROGRESS: at 99.89% examples, 489947 words/s, in_qsize 2, out_qsize 1
# 2018-04-18 17:12:18,637 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-18 17:12:18,660 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-18 17:12:18,665 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 17:12:18,666 : INFO : EPOCH - 2 : training on 17798270 raw words (12874729 effective words) took 26.3s, 489909 effective words/s
# 2018-04-18 17:12:19,712 : INFO : EPOCH 3 - PROGRESS: at 3.02% examples, 386409 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:20,718 : INFO : EPOCH 3 - PROGRESS: at 5.60% examples, 358338 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:21,734 : INFO : EPOCH 3 - PROGRESS: at 8.56% examples, 361844 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:22,735 : INFO : EPOCH 3 - PROGRESS: at 11.32% examples, 359815 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:23,765 : INFO : EPOCH 3 - PROGRESS: at 14.11% examples, 356524 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:24,781 : INFO : EPOCH 3 - PROGRESS: at 17.36% examples, 364589 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:25,791 : INFO : EPOCH 3 - PROGRESS: at 20.96% examples, 377852 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:26,807 : INFO : EPOCH 3 - PROGRESS: at 25.28% examples, 399100 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:27,809 : INFO : EPOCH 3 - PROGRESS: at 29.36% examples, 413002 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:28,821 : INFO : EPOCH 3 - PROGRESS: at 33.88% examples, 427967 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:29,835 : INFO : EPOCH 3 - PROGRESS: at 37.45% examples, 430481 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:30,879 : INFO : EPOCH 3 - PROGRESS: at 40.74% examples, 428560 words/s, in_qsize 6, out_qsize 1
# 2018-04-18 17:12:31,878 : INFO : EPOCH 3 - PROGRESS: at 44.95% examples, 437143 words/s, in_qsize 8, out_qsize 1
# 2018-04-18 17:12:32,879 : INFO : EPOCH 3 - PROGRESS: at 49.21% examples, 445484 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:33,887 : INFO : EPOCH 3 - PROGRESS: at 53.67% examples, 453471 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:34,901 : INFO : EPOCH 3 - PROGRESS: at 57.15% examples, 453148 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:35,904 : INFO : EPOCH 3 - PROGRESS: at 61.13% examples, 456961 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:36,907 : INFO : EPOCH 3 - PROGRESS: at 65.23% examples, 460770 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:37,925 : INFO : EPOCH 3 - PROGRESS: at 69.25% examples, 463387 words/s, in_qsize 6, out_qsize 1
# 2018-04-18 17:12:38,934 : INFO : EPOCH 3 - PROGRESS: at 73.22% examples, 465638 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:39,943 : INFO : EPOCH 3 - PROGRESS: at 77.10% examples, 466977 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:40,943 : INFO : EPOCH 3 - PROGRESS: at 81.15% examples, 469311 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:41,944 : INFO : EPOCH 3 - PROGRESS: at 85.40% examples, 472719 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:42,951 : INFO : EPOCH 3 - PROGRESS: at 89.74% examples, 476324 words/s, in_qsize 6, out_qsize 0
# 2018-04-18 17:12:43,987 : INFO : EPOCH 3 - PROGRESS: at 93.97% examples, 478208 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:44,989 : INFO : EPOCH 3 - PROGRESS: at 97.62% examples, 477833 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:45,569 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-04-18 17:12:45,585 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-18 17:12:45,606 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-18 17:12:45,611 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 17:12:45,612 : INFO : EPOCH - 3 : training on 17798270 raw words (12870193 effective words) took 26.9s, 478290 effective words/s
# 2018-04-18 17:12:46,644 : INFO : EPOCH 4 - PROGRESS: at 3.87% examples, 493100 words/s, in_qsize 8, out_qsize 1
# 2018-04-18 17:12:47,643 : INFO : EPOCH 4 - PROGRESS: at 8.06% examples, 513097 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:48,651 : INFO : EPOCH 4 - PROGRESS: at 12.18% examples, 516661 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:49,677 : INFO : EPOCH 4 - PROGRESS: at 15.56% examples, 492722 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:50,694 : INFO : EPOCH 4 - PROGRESS: at 18.92% examples, 477781 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:51,704 : INFO : EPOCH 4 - PROGRESS: at 22.54% examples, 474462 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:52,712 : INFO : EPOCH 4 - PROGRESS: at 26.02% examples, 470143 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:53,713 : INFO : EPOCH 4 - PROGRESS: at 29.42% examples, 466275 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:54,723 : INFO : EPOCH 4 - PROGRESS: at 32.29% examples, 454148 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:55,739 : INFO : EPOCH 4 - PROGRESS: at 35.56% examples, 449885 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:56,742 : INFO : EPOCH 4 - PROGRESS: at 37.62% examples, 433270 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:12:57,763 : INFO : EPOCH 4 - PROGRESS: at 39.90% examples, 421266 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:12:58,763 : INFO : EPOCH 4 - PROGRESS: at 42.30% examples, 412830 words/s, in_qsize 8, out_qsize 1
# 2018-04-18 17:12:59,783 : INFO : EPOCH 4 - PROGRESS: at 45.06% examples, 408057 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:00,787 : INFO : EPOCH 4 - PROGRESS: at 47.84% examples, 404814 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:01,823 : INFO : EPOCH 4 - PROGRESS: at 50.45% examples, 399876 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:02,830 : INFO : EPOCH 4 - PROGRESS: at 52.72% examples, 393278 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:03,837 : INFO : EPOCH 4 - PROGRESS: at 54.49% examples, 384194 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:04,850 : INFO : EPOCH 4 - PROGRESS: at 56.38% examples, 376712 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:05,979 : INFO : EPOCH 4 - PROGRESS: at 58.07% examples, 366799 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:06,988 : INFO : EPOCH 4 - PROGRESS: at 60.25% examples, 362706 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:08,033 : INFO : EPOCH 4 - PROGRESS: at 62.49% examples, 358656 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:09,099 : INFO : EPOCH 4 - PROGRESS: at 64.89% examples, 355603 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:10,135 : INFO : EPOCH 4 - PROGRESS: at 66.52% examples, 349124 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:11,139 : INFO : EPOCH 4 - PROGRESS: at 68.43% examples, 344991 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:12,174 : INFO : EPOCH 4 - PROGRESS: at 70.33% examples, 340787 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:13,197 : INFO : EPOCH 4 - PROGRESS: at 72.37% examples, 337841 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:14,227 : INFO : EPOCH 4 - PROGRESS: at 75.36% examples, 339064 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:15,230 : INFO : EPOCH 4 - PROGRESS: at 77.66% examples, 337577 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:16,246 : INFO : EPOCH 4 - PROGRESS: at 79.80% examples, 335320 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:17,252 : INFO : EPOCH 4 - PROGRESS: at 81.86% examples, 333100 words/s, in_qsize 8, out_qsize 1
# 2018-04-18 17:13:18,261 : INFO : EPOCH 4 - PROGRESS: at 84.88% examples, 334761 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:19,260 : INFO : EPOCH 4 - PROGRESS: at 87.31% examples, 334031 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:20,273 : INFO : EPOCH 4 - PROGRESS: at 90.24% examples, 335316 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:21,275 : INFO : EPOCH 4 - PROGRESS: at 93.06% examples, 336021 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:22,291 : INFO : EPOCH 4 - PROGRESS: at 96.19% examples, 337529 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:23,299 : INFO : EPOCH 4 - PROGRESS: at 99.27% examples, 339239 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:23,487 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-04-18 17:13:23,499 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-18 17:13:23,533 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-18 17:13:23,541 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 17:13:23,542 : INFO : EPOCH - 4 : training on 17798270 raw words (12871539 effective words) took 37.9s, 339530 effective words/s
# 2018-04-18 17:13:24,597 : INFO : EPOCH 5 - PROGRESS: at 2.62% examples, 333147 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:25,622 : INFO : EPOCH 5 - PROGRESS: at 5.25% examples, 331866 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:26,692 : INFO : EPOCH 5 - PROGRESS: at 8.33% examples, 342938 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:27,696 : INFO : EPOCH 5 - PROGRESS: at 11.14% examples, 347081 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:28,697 : INFO : EPOCH 5 - PROGRESS: at 14.34% examples, 358240 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:29,726 : INFO : EPOCH 5 - PROGRESS: at 17.69% examples, 367529 words/s, in_qsize 8, out_qsize 1
# 2018-04-18 17:13:30,744 : INFO : EPOCH 5 - PROGRESS: at 20.89% examples, 372829 words/s, in_qsize 8, out_qsize 1
# 2018-04-18 17:13:31,768 : INFO : EPOCH 5 - PROGRESS: at 24.15% examples, 377413 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:32,771 : INFO : EPOCH 5 - PROGRESS: at 27.42% examples, 381701 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:33,801 : INFO : EPOCH 5 - PROGRESS: at 30.50% examples, 382043 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:34,820 : INFO : EPOCH 5 - PROGRESS: at 33.21% examples, 377587 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:35,821 : INFO : EPOCH 5 - PROGRESS: at 35.78% examples, 373784 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:36,831 : INFO : EPOCH 5 - PROGRESS: at 38.45% examples, 371439 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:37,845 : INFO : EPOCH 5 - PROGRESS: at 41.09% examples, 368846 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:38,848 : INFO : EPOCH 5 - PROGRESS: at 43.69% examples, 366846 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:39,851 : INFO : EPOCH 5 - PROGRESS: at 46.83% examples, 369091 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:40,854 : INFO : EPOCH 5 - PROGRESS: at 50.00% examples, 371474 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:41,869 : INFO : EPOCH 5 - PROGRESS: at 53.16% examples, 372978 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:42,869 : INFO : EPOCH 5 - PROGRESS: at 56.21% examples, 374211 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:43,874 : INFO : EPOCH 5 - PROGRESS: at 59.39% examples, 376341 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:44,929 : INFO : EPOCH 5 - PROGRESS: at 61.81% examples, 372296 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:45,932 : INFO : EPOCH 5 - PROGRESS: at 64.73% examples, 372387 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:46,948 : INFO : EPOCH 5 - PROGRESS: at 67.81% examples, 373182 words/s, in_qsize 8, out_qsize 1
# 2018-04-18 17:13:47,965 : INFO : EPOCH 5 - PROGRESS: at 70.88% examples, 373922 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:48,974 : INFO : EPOCH 5 - PROGRESS: at 73.44% examples, 372136 words/s, in_qsize 7, out_qsize 1
# 2018-04-18 17:13:49,985 : INFO : EPOCH 5 - PROGRESS: at 78.00% examples, 380046 words/s, in_qsize 8, out_qsize 0
# 2018-04-18 17:13:50,998 : INFO : EPOCH 5 - PROGRESS: at 82.44% examples, 386804 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:52,002 : INFO : EPOCH 5 - PROGRESS: at 86.92% examples, 393479 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:53,010 : INFO : EPOCH 5 - PROGRESS: at 91.26% examples, 399140 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:54,021 : INFO : EPOCH 5 - PROGRESS: at 95.91% examples, 405351 words/s, in_qsize 7, out_qsize 0
# 2018-04-18 17:13:54,946 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-04-18 17:13:54,977 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-04-18 17:13:54,978 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-04-18 17:13:54,988 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-04-18 17:13:54,989 : INFO : EPOCH - 5 : training on 17798270 raw words (12873907 effective words) took 31.4s, 409830 effective words/s
# 2018-04-18 17:13:54,991 : INFO : training on a 88991350 raw words (64363979 effective words) took 152.7s, 421511 effective words/s

# %%
# 학습이 완료 되면 필요없는 메모리를 unload 시킨다.
model.init_sims(replace=True)

model_name = '300features_40minwords_10text'
# model_name = '300features_50minwords_20text'
model.save(model_name)
# Out:
# 2018-04-18 17:16:30,416 : INFO : precomputing L2-norms of word weight vectors
# 2018-04-18 17:16:30,579 : INFO : saving Word2Vec object under 300features_40minwords_10text, separately None
# 2018-04-18 17:16:30,593 : INFO : not storing attribute vectors_norm
# 2018-04-18 17:16:30,604 : INFO : not storing attribute cum_table
# 2018-04-18 17:16:31,757 : INFO : saved 300features_40minwords_10text

# %%
# 유사도가 없는 단어 추출
model.wv.doesnt_match('man woman child kitchen'.split())
# Out:
# 'kitchen'

# %%
model.wv.doesnt_match("france england germany berlin".split())
# Out:
# 2018-04-18 17:16:39,816 : WARNING : vectors for words {'germany', 'france'} are not present in the model, ignoring these words
# 'berlin'

# %%
# 가장 유사한 단어를 추출
model.wv.most_similar("man")
# Out:
# [('woman', 0.6455962061882019),
#  ('businessman', 0.510991096496582),
#  ('millionair', 0.5008515119552612),
#  ('ladi', 0.4981335997581482),
#  ('lad', 0.49504709243774414),
#  ('widow', 0.47404539585113525),
#  ('men', 0.4629068970680237),
#  ('billionair', 0.4625746011734009),
#  ('doctor', 0.4623534381389618),
#  ('lawyer', 0.4603825807571411)]

# %%
model.wv.most_similar("queen")
# Out:
# [('princess', 0.6186563968658447),
#  ('victoria', 0.5793728232383728),
#  ('madam', 0.5658301115036011),
#  ('latifah', 0.5642294883728027),
#  ('stepmoth', 0.5587388873100281),
#  ('countess', 0.5580689907073975),
#  ('duchess', 0.5517499446868896),
#  ('antoinett', 0.5388837456703186),
#  ('mistress', 0.5358436107635498),
#  ('regina', 0.5324931144714355)]

# %%
# model.wv.most_similar("happy")
model.wv.most_similar("happi") # stemming 처리 시
# Out:
# [('unhappi', 0.4372105002403259),
#  ('sad', 0.42206454277038574),
#  ('satisfi', 0.3913938105106354),
#  ('happier', 0.377570241689682),
#  ('afraid', 0.37706080079078674),
#  ('sappi', 0.3670363128185272),
#  ('comfort', 0.366341233253479),
#  ('glad', 0.3615718483924866),
#  ('bitter', 0.36094674468040466),
#  ('lucki', 0.35873594880104065)]

# %%
# 참고 https://stackoverflow.com/questions/43776572/visualise-word2vec-generated-from-gensim
from sklearn.manifold import TSNE
import matplotlib as mpl
import matplotlib.pyplot as plt
import gensim 
import gensim.models as g

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

model_name = '300features_40minwords_10text'
model = g.Doc2Vec.load(model_name)

vocab = list(model.wv.vocab)
X = model[vocab]

print(len(X))
print(X[0][:10])
tsne = TSNE(n_components=2)

# 100개의 단어에 대해서만 시각화
X_tsne = tsne.fit_transform(X[:100,:])
# X_tsne = tsne.fit_transform(X)
# Out:
# 2018-04-18 17:17:09,750 : INFO : loading Doc2Vec object from 300features_40minwords_10text
# 2018-04-18 17:17:10,107 : INFO : loading wv recursively from 300features_40minwords_10text.wv.* with mmap=None
# 2018-04-18 17:17:10,109 : INFO : setting ignored attribute vectors_norm to None
# 2018-04-18 17:17:10,110 : INFO : loading vocabulary recursively from 300features_40minwords_10text.vocabulary.* with mmap=None
# 2018-04-18 17:17:10,113 : INFO : loading trainables recursively from 300features_40minwords_10text.trainables.* with mmap=None
# 2018-04-18 17:17:10,118 : INFO : setting ignored attribute cum_table to None
# 2018-04-18 17:17:10,122 : INFO : loaded 300features_40minwords_10text
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   from ipykernel import kernelapp as app
# 11986
# [-0.00405244 -0.04393338  0.02327532  0.00611522  0.03493676  0.12559651
#  -0.16493465  0.05255285  0.07809427  0.03239263]

# %%
df = pd.DataFrame(X_tsne, index=vocab[:100], columns=['x', 'y'])
df.shape
# Out:
# (100, 2)

# %%
df.head(10)
# Out:
#                 x          y
# with   -14.200181   5.427143
# all     -1.380511   6.828491
# this     6.330678  -2.005665
# stuff   10.941723  -1.083465
# go       3.309034 -17.628311
# down   -19.720673   8.620927
# at     -19.558174  14.072529
# the     -5.001111   8.451332
# moment   8.049493  10.542526
# mj     -25.131575  -1.620774

# %%
fig = plt.figure()
fig.set_size_inches(40, 20)
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])

for word, pos in df.iterrows():
    ax.annotate(word, pos, fontsize=30)
plt.show()

# %%
import numpy as np

def makeFeatureVec(words, model, num_features):
    """
    주어진 문장에서 단어 벡터의 평균을 구하는 함수
    """
    # 속도를 위해 0으로 채운 배열로 초기화 한다.
    featureVec = np.zeros((num_features,),dtype="float32")

    nwords = 0.
    # Index2word는 모델의 사전에 있는 단어명을 담은 리스트이다.
    # 속도를 위해 set 형태로 초기화 한다.
    index2word_set = set(model.wv.index2word)
    # 루프를 돌며 모델 사전에 포함이 되는 단어라면 피처에 추가한다.
    for word in words:
        if word in index2word_set:
            nwords = nwords + 1.
            featureVec = np.add(featureVec,model[word])
    # 결과를 단어수로 나누어 평균을 구한다.
    featureVec = np.divide(featureVec,nwords)
    return featureVec

# %%
def getAvgFeatureVecs(reviews, model, num_features):
    # 리뷰 단어 목록의 각각에 대한 평균 feature 벡터를 계산하고 
    # 2D numpy 배열을 반환한다.
    
    # 카운터를 초기화 한다.
    counter = 0.
    # 속도를 위해 2D 넘파이 배열을 미리 할당한다.
    reviewFeatureVecs = np.zeros(
        (len(reviews),num_features),dtype="float32")
    
    for review in reviews:
       # 매 1000개 리뷰마다 상태를 출력
       if counter%1000. == 0.:
           print("Review %d of %d" % (counter, len(reviews)))
       # 평균 피처 벡터를 만들기 위해 위에서 정의한 함수를 호출한다.
       reviewFeatureVecs[int(counter)] = makeFeatureVec(review, model, \
           num_features)
       # 카운터를 증가시킨다.
       counter = counter + 1.
    return reviewFeatureVecs

# %%
# 멀티스레드로 4개의 워커를 사용해 처리한다.
def getCleanReviews(reviews):
    clean_reviews = []
    clean_reviews = kaggleBagofWord.apply_by_multiprocessing(\
        reviews["review"], kaggleBagofWord.review_to_wordlist,\
        workers=4)
    return clean_reviews

# %%
# %time trainDataVecs = getAvgFeatureVecs(\
    getCleanReviews(train), model, num_features )
# Out:
# Review 0 of 25000
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Review 1000 of 25000
# Review 2000 of 25000
# Review 3000 of 25000
# Review 4000 of 25000
# Review 5000 of 25000
# Review 6000 of 25000
# Review 7000 of 25000
# Review 8000 of 25000
# Review 9000 of 25000
# Review 10000 of 25000
# Review 11000 of 25000
# Review 12000 of 25000
# Review 13000 of 25000
# Review 14000 of 25000
# Review 15000 of 25000
# Review 16000 of 25000
# Review 17000 of 25000
# Review 18000 of 25000
# Review 19000 of 25000
# Review 20000 of 25000
# Review 21000 of 25000
# Review 22000 of 25000
# Review 23000 of 25000
# Review 24000 of 25000
# Wall time: 2min 43s

# %%
# %time testDataVecs = getAvgFeatureVecs(\
        getCleanReviews(test), model, num_features )
# Out:
# Review 0 of 25000
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# Review 1000 of 25000
# Review 2000 of 25000
# Review 3000 of 25000
# Review 4000 of 25000
# Review 5000 of 25000
# Review 6000 of 25000
# Review 7000 of 25000
# Review 8000 of 25000
# Review 9000 of 25000
# Review 10000 of 25000
# Review 11000 of 25000
# Review 12000 of 25000
# Review 13000 of 25000
# Review 14000 of 25000
# Review 15000 of 25000
# Review 16000 of 25000
# Review 17000 of 25000
# Review 18000 of 25000
# Review 19000 of 25000
# Review 20000 of 25000
# Review 21000 of 25000
# Review 22000 of 25000
# Review 23000 of 25000
# Review 24000 of 25000
# Wall time: 2min 28s

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(
    n_estimators = 100, n_jobs = -1, random_state=2018)

# %%
# %time forest = forest.fit( trainDataVecs, train["sentiment"] )
# Out:
# Wall time: 21.1 s

# %%
from sklearn.model_selection import cross_val_score
# %time score = np.mean(cross_val_score(\
    forest, trainDataVecs, \
    train['sentiment'], cv=10, scoring='roc_auc'))
# Out:
# Wall time: 3min 18s

# %%
score
# Out:
# 0.904642208

# %%
result = forest.predict( testDataVecs )

# %%
output = pd.DataFrame( data={"id":test["id"], "sentiment":result} )
output.to_csv('data/Word2Vec_AverageVectors_{0:.5f}.csv'.format(score), 
              index=False, quoting=3 )

# %%
output_sentiment = output['sentiment'].value_counts()
print(output_sentiment[0] - output_sentiment[1])
output_sentiment
# Out:
# 66
# 0    12533
# 1    12467
# Name: sentiment, dtype: int64

# %%
import seaborn as sns 
# %matplotlib inline

fig, axes = plt.subplots(ncols=2)
fig.set_size_inches(12,5)
sns.countplot(train['sentiment'], ax=axes[0])
sns.countplot(output['sentiment'], ax=axes[1])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 성능 개선을 위해 Vector averaging 대신
# tf-idf 혹은 Clusturing 사용할 수 있다.
