# %%
import os

# %%
LABEL_PATH="../../data/label"
PAPER_PATH="../../data/paper"

# %% [markdown]
# 경로내의 파일 리스트를 받아옵니다.

# %%
label_list=os.listdir(LABEL_PATH)
paper_list=os.listdir(PAPER_PATH)

# %%
label_dic={}
for label_el in label_list:
    label_dic[label_el]=1

# %%
proc_dic={}
for paper_el in paper_list:
    if label_dic.get(paper_el, 0) == 1:
        proc_dic[paper_el]=1
    elif label_dic.get(paper_el, 0) == 0:
        proc_dic[paper_el]=10
    else:
        print("Special-case" + paper_el)

# %%
import pandas as pd

# %% [markdown]
# 파일을 읽어 1개의 문서로 만들기 위한 함수입니다.

# %%
def file2df(filePath):
    ret=""
    with open(filePath, "r") as f:
        for line in f:
            ret = ret + line.replace("\n"," ")
        if len(ret) < 10:
            ret="No data"
    return ret

# %%
col_names=["labels","papers"]

# %% [markdown]
# 데이터가 있는 경로에서 파일을 읽어서 labels, papers 행으로 이루어진 DataFrame을 만듭니다.

# %%
dfs = pd.DataFrame(columns=col_names)
for ky, vl in proc_dic.items():
    if proc_dic[ky] == 1:
        dfs=pd.concat([dfs, pd.DataFrame([[file2df(LABEL_PATH+"/"+ky),file2df(PAPER_PATH+"/"+ky)]], columns=col_names)], ignore_index=True)

# %%
dfs
# Out:
#                                                labels  \
# 0   .  Intrusion  detection for computer network s...
# 1    It is well-known that the robustness of artiﬁ...
# 2   . The present work shows the application of tr...
# 3    The linearly constrained nonconvex nonsmooth ...
# 4    This paper deals with the reality gap from a ...
# 5    Gaussian processes (GPs) are ﬂexible models t...
# 6   —We present a fast Compressive Sensing algorit...
# 7    We identify obfuscated gradients as a phe- no...
# 8   —Unsupervised feature extractors are known to ...
# 9    Relational data sources are still one of the ...
# 10   The robustness of neural networks to adversar...
# 11  —Model interpretability is a requirement in ma...
# 12   Model pruning has become a useful technique t...
# 13   Systematic reviews are essential to summarizi...
# 14  —In the last decade, an active area of researc...
# 15   Clustering is inherently ill-posed: there oft...
# 16   Accurate, reliable sampling from fully-connec...
# 17   While neural networks have achieved high accu...
# 18  Oneofthecoretaskinmulti-viewlearningistocaptur...
# 19   Recurrent neural networks have achieved excel...
# 20   Deep neural networks are among the most influ...
# 21  —In this era of data deluge, many signal proce...
# 22   Tactical driving decision making is crucial f...
# 23  Predictingconversionrates(CVRs)indisplayad-ver...
# 24   We consider the problem of retrieving objects...
# 25  —Non-recurring trafﬁc congestion is caused by ...
# 26   We consider the matrix completion problem wit...
# 27  —In this paper, we present a new approach of d...
# 28   The backpropagation algorithm, which had been...
# 29   Linear approximations to the decision boundar...
# ..                                                ...
# 50   We propose two general and falsiﬁable hypothe...
# 51   In model-based reinforcement learning it is t...
# 52   Recurrent models for sequences have been rece...
# 53  Thislarge-scalestudy,consistingof21.3millionha...
# 54  —Clustering is essential to many tasks in patt...
# 55   Though deep neural networks (DNNs) achieve re...
# 56   Rademacher complexity is often used to charac...
# 57  Motivation:Theuseofmultipledrugs,termedpolypha...
# 58   Convolutional Neural Networks (CNNs) have bec...
# 59  . We introduce a new metric for measuring how ...
# 60   Dimensionality reduction is in demand to redu...
# 61   The identification of novel drug-target (DT) ...
# 62  —The artificial neural network shows powerful ...
# 63  —Methods exploiting sparsity have been popular...
# 64  — The need to predict or ﬁll-in missing data, ...
# 65   In this work, we present a fully automated lu...
# 66   Pretraining with expert demonstrations have b...
# 67  . For 50 years, research in the area of induct...
# 68  . We propose a new method to eﬃciently compute...
# 69   We present a class of algorithms capable of d...
# 70  Brain-relateddisorderssuchasepilepsycanbediagn...
# 71   We present a novel algorithm, called Links, d...
# 72   Deep neural networks are complex and opaque. ...
# 73   It is desirable to train convolutional networ...
# 74                                            No data
# 75  —In this paper, we propose a novel approach, 3...
# 76  . The extension of deep learning towards tempo...
# 77   Incremental versions of batch algorithms are ...
# 78   Sigma-Pi-Sigma neural networks (SPSNNs) as a ...
# 79   Sensitivity based sampling is crucial for con...
#
#                                                papers
# 0     Network anomaly detection refers to the prob...
# 1    Lots of biological experiments and theoretica...
# 2    The wheat is the main source of nutrients to ...
# 3    In this paper, we are aiming at developing an...
# 4    Pioneered by the Deep Q-network [Mnih et al.,...
# 5    Gaussian Processes (GPs) [Rasmussen, 2004] ar...
# 6    Compressive Sensing (CS) is a method in signa...
# 7    In response to the susceptibility of neural n...
# 8    D EEP learning (DL) networks take the form of...
# 9    An important problem in database research is ...
# 10   Recent studies have highlighted the lack of r...
# 11   With the fast development of sophisticated ma...
# 12   Not all computations in a deep neural network...
# 13   Systematic reviews are essential in various d...
# 14   In the last decade, deep learning has achieve...
# 15   Clustering is inherently subjective [Caruana ...
# 16   As the results of the 2016 US Presidential El...
# 17   Despite the impressive (and sometimes even su...
# 18  Inmulti-viewlearning,datacanbenaturallypartiti...
# 19   Recurrent neural networks (RNNs) are speciﬁc ...
# 20   Deep Neural Network (DNN) architectures are p...
# 21   The massive development of connected devices ...
# 22   Autonomous driving has attracted considerable...
# 23  Predictingconversionrates(CVRs)indisplayadvert...
# 24   Unsupervised discovery of common patterns is ...
# 25   Emerging Trends. Trafﬁc congestion in urban a...
# 26   Matrix completion (e.g., [4,5,13]) is a funda...
# 27   Spatio-temporal datasets are often very large...
# 28   Artiﬁcial Neural Network (ANN), inspired by b...
# 29   Model interpretability is a long-standing pro...
# ..                                                ...
# 50   The world is dynamic, in a constant state of ...
# 51   In the reinforcement learning problem, an age...
# 52   long history in deep learning (Hinton & Salak...
# 53  Healthcareassociatedinfectionsrepresentamajorc...
# 54   Cluster analysis is essential to many applica...
# 55   Over the last few decades, many initializatio...
# 56   A wide variety of problems can be reduced to ...
# 57  Mosthumandiseasesarecausedbycomplexbiologicalp...
# 58   Convolutional networks are able to detect loc...
# 59   In a wide range of ﬁelds, from music and adve...
# 60   This paper studies the Restricted Isometry Pr...
# 61   The successful identification of drug-target ...
# 62     With decades of development, the artificial...
# 63   Various models of signals and images have bee...
# 64   Data acquisition and analysis is ubiquitous, ...
# 65   Lung cancer is the most common cause of cance...
# 66   Deep reinforcement learning is a general meth...
# 67   Imagine we are interested in setting up a cla...
# 68  system security analysis with Guided Dropout B...
# 69   As deep learning penetrates more and more app...
# 70  Electroencephalography(EEG)isanoninvasivemetho...
# 71   Although a wide selection of clustering metho...
# 72   Artiﬁcial intelligence (AI)-enabled systems a...
# 73   Convolutional networks (CNNs) have greatly ac...
# 74    A network anomaly is a deviation from the no...
# 75   T O reconstruct the complete and precise 3D g...
# 76   Deep learning is an attractive area of resear...
# 77   Kernel methods make use of non-linear pattern...
# 78   Sigma-Pi-Sigma neural networks (SPSNNs) [1,4,...
# 79   1.1 Related Works . . . . . . . . . . . . . ....
#
# [80 rows x 2 columns]

# %% [markdown]
# DataFrame을 백업합니다.

# %%
dfs.to_pickle("source_df.pickle")
