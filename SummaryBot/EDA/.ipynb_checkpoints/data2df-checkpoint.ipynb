# %%
import os

# %%
LABEL_PATH="../data/label"
PAPER_PATH="../data/paper"

# %%
label_list=os.listdir(LABEL_PATH)
paper_list=os.listdir(PAPER_PATH)

# %%
label_dic={}
for label_el in label_list:
    label_dic[label_el]=1

# %%
proc_dic={}
for paper_el in paper_list:
    if label_dic.get(paper_el, 0) == 1:
        proc_dic[paper_el]=1
    elif label_dic.get(paper_el, 0) == 0:
        proc_dic[paper_el]=10
    else:
        print("Special-case" + paper_el)

# %%
import pandas as pd

# %%
def file2df(filePath):
    ret=""
    with open(filePath, "r") as f:
        for line in f:
            ret = ret + line.replace("\n"," ")
        if len(ret) < 10:
            ret="No data"
    return ret

# %%
col_names=["labels","papers"]

# %%
dfs = pd.DataFrame(columns=col_names)
for ky, vl in proc_dic.items():
    if proc_dic[ky] == 1:
        dfs=pd.concat([dfs, pd.DataFrame([[file2df(LABEL_PATH+"/"+ky),file2df(PAPER_PATH+"/"+ky)]], columns=col_names)], ignore_index=True)

# %%
dfs
# Out:
#                                                labels  \
# 0   —In this paper, we present a new approach of d...
# 1    The identification of novel drug-target (DT) ...
# 2    Relational data sources are still one of the ...
# 3    Deep learning involves a difﬁcult non-convex ...
# 4   —Unsupervised feature extractors are known to ...
# 5    We present a novel algorithm, called Links, d...
# 6    We algorithmically construct multi-output Gau...
# 7    Recurrent neural networks have achieved excel...
# 8   . Recent advances in analysis of subband ampli...
# 9    Systematic reviews are essential to summarizi...
# 10   We consider the problem of retrieving objects...
# 11    The most common type of arrhythmia is atrial...
# 12  —We present a fast Compressive Sensing algorit...
# 13   The linearly constrained nonconvex nonsmooth ...
# 14  — The need to predict or ﬁll-in missing data, ...
# 15   In this work, we present a fully automated lu...
# 16  —Model interpretability is a requirement in ma...
# 17   Projective cone scheduling deﬁnes a large cla...
# 18   The linear model uses the space deﬁned by the...
# 19   We consider high dimensional dynamic multi-pr...
# 20  Thislarge-scalestudy,consistingof21.3millionha...
# 21   Texture is a fundamental characteristic of ma...
# 22  —In this paper, we propose a novel approach, 3...
# 23   We propose two general and falsiﬁable hypothe...
# 24  —Non-recurring trafﬁc congestion is caused by ...
# 25  Oneofthecoretaskinmulti-viewlearningistocaptur...
# 26   Convolutional Neural Networks (CNNs) have bec...
# 27  —In the last decade, an active area of researc...
# 28   The backpropagation algorithm, which had been...
# 29                                            No data
# ..                                                ...
# 50  . We introduce a new metric for measuring how ...
# 51   This paper presents methods to accelerate rec...
# 52   It is desirable to train convolutional networ...
# 53   We consider the matrix completion problem wit...
# 54   Rademacher complexity is often used to charac...
# 55  —In this era of data deluge, many signal proce...
# 56   Deep neural networks are among the most influ...
# 57   Linear approximations to the decision boundar...
# 58  Brain-relateddisorderssuchasepilepsycanbediagn...
# 59   We identify obfuscated gradients as a phe- no...
# 60  . The extension of deep learning towards tempo...
# 61   Gaussian processes are rich distributions ove...
# 62  . For 50 years, research in the area of induct...
# 63   Tactical driving decision making is crucial f...
# 64   The robustness of neural networks to adversar...
# 65  Predictingconversionrates(CVRs)indisplayad-ver...
# 66    The  development  of  accurate  and  transfe...
# 67   It is well-known that the robustness of artiﬁ...
# 68  Motivation:Theuseofmultipledrugs,termedpolypha...
# 69    Our purpose was to develop a deep learning a...
# 70  . We propose a new method to eﬃciently compute...
# 71   Dimensionality reduction is in demand to redu...
# 72   Pretraining with expert demonstrations have b...
# 73   Though deep neural networks (DNNs) achieve re...
# 74  —Thispaperpresentsasafety-awarelearningframe-w...
# 75   In this paper, we introduce ”Power Linear Uni...
# 76  —We study the problem of learning to rank from...
# 77   While neural networks have achieved high accu...
# 78  .  Intrusion  detection for computer network s...
# 79  —The artificial neural network shows powerful ...
#
#                                                papers
# 0    Spatio-temporal datasets are often very large...
# 1    The successful identification of drug-target ...
# 2    An important problem in database research is ...
# 3    Recently deep learning has emerged as a usefu...
# 4    D EEP learning (DL) networks take the form of...
# 5    Although a wide selection of clustering metho...
# 6    In recent years, Gaussian process regression ...
# 7    Recurrent neural networks (RNNs) are speciﬁc ...
# 8    Computational models for generating audio sig...
# 9    Systematic reviews are essential in various d...
# 10   Unsupervised discovery of common patterns is ...
# 11    relaxation).  QRS  complex  Electrocardiogra...
# 12   Compressive Sensing (CS) is a method in signa...
# 13   In this paper, we are aiming at developing an...
# 14   Data acquisition and analysis is ubiquitous, ...
# 15   Lung cancer is the most common cause of cance...
# 16   With the fast development of sophisticated ma...
# 17   In a variety of application areas, processing...
# 18   Since the early work of Legendre and Gauss in...
# 19   In this work, we consider a seller oﬀering N ...
# 20  Healthcareassociatedinfectionsrepresentamajorc...
# 21   Our visual world is richly ﬁlled with a great...
# 22   T O reconstruct the complete and precise 3D g...
# 23   The world is dynamic, in a constant state of ...
# 24   Emerging Trends. Trafﬁc congestion in urban a...
# 25  Inmulti-viewlearning,datacanbenaturallypartiti...
# 26   Convolutional networks are able to detect loc...
# 27   In the last decade, deep learning has achieve...
# 28   Artiﬁcial Neural Network (ANN), inspired by b...
# 29   Creating a model of a computer system that ca...
# ..                                                ...
# 50   In a wide range of ﬁelds, from music and adve...
# 51   A language model (LM) computes the likelihood...
# 52   Convolutional networks (CNNs) have greatly ac...
# 53   Matrix completion (e.g., [4,5,13]) is a funda...
# 54   A wide variety of problems can be reduced to ...
# 55   The massive development of connected devices ...
# 56   Deep Neural Network (DNN) architectures are p...
# 57   Model interpretability is a long-standing pro...
# 58  Electroencephalography(EEG)isanoninvasivemetho...
# 59   In response to the susceptibility of neural n...
# 60   Deep learning is an attractive area of resear...
# 61   Gaussian processes (GPs) naturally give rise ...
# 62   Imagine we are interested in setting up a cla...
# 63   Autonomous driving has attracted considerable...
# 64   Recent studies have highlighted the lack of r...
# 65  Predictingconversionrates(CVRs)indisplayadvert...
# 66    The development of accurate force fields1–3 ...
# 67   Lots of biological experiments and theoretica...
# 68  Mosthumandiseasesarecausedbycomplexbiologicalp...
# 69    Cerebrovascular diseases are common causes o...
# 70  system security analysis with Guided Dropout B...
# 71   This paper studies the Restricted Isometry Pr...
# 72   Deep reinforcement learning is a general meth...
# 73   Over the last few decades, many initializatio...
# 74  Byexploringandinteractingwithanenvironment,rei...
# 75   In recent years, neural networks with many hi...
# 76   Learning to rank is an important research top...
# 77   Despite the impressive (and sometimes even su...
# 78    Network anomaly detection refers to the prob...
# 79     With decades of development, the artificial...
#
# [80 rows x 2 columns]

# %%
dfs.to_pickle("source_df.pickle")
